# %%
import pandas as pd

df = pd.read_csv('../Data/SMTO_2015/SMTO_2015_Complete_Input.csv')
df.head()
# Out:
#                           Campus Level Status  Mode_Actual  Gender  Licence  \
# 0             Scarborough (UTSC)    UG     FT  Transit Bus  Female        0
# 1  Downtown Toronto (St. George)  Grad     FT         Walk  Female        1
# 2  Downtown Toronto (St. George)    UG     FT  Transit Bus  Female        1
# 3  Downtown Toronto (St. George)    UG     FT         Walk    Male        1
# 4  Downtown Toronto (St. George)  Grad     FT         Walk    Male        1
#
#       Work  Age  HomeZone  Family  ...  Domestic.OC  Admission_Avg.SG  \
# 0  Unknown   20       261       1  ...       0.8998             0.893
# 1  Unknown   25        71       0  ...       0.6786             0.893
# 2  Unknown   23      3714       1  ...       0.8998             0.893
# 3  Unknown   20        74       0  ...       0.8998             0.893
# 4  Unknown   27        71       0  ...       0.6786             0.893
#
#    Admission_Avg.SC Admission_Avg.MI Admission_Avg.YK Admission_Avg.YG  \
# 0             0.841             0.83            0.817            0.817
# 1             0.841             0.83            0.817            0.817
# 2             0.841             0.83            0.817            0.817
# 3             0.841             0.83            0.817            0.817
# 4             0.841             0.83            0.817            0.817
#
#    Admission_Avg.RY  Admission_Avg.OC  Exp_Segment  Exp_Level
# 0              0.84             0.824     0.383705   0.383705
# 1              0.84             0.824     0.986085   0.986085
# 2              0.84             0.824     0.919270   0.919270
# 3              0.84             0.824     0.919270   0.919270
# 4              0.84             0.824     0.986085   0.986085
#
# [5 rows x 89 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(n_estimators=100)
y = df['School_Codes']

# %%
full_zones_df = pd.read_csv('../Data/Full_Zones_Dists.csv')

def run_model(x_train, x_test, colname):
    """
    Run model called name given input x_train
    on full zones data x_test
    and send model predictions to full_zones_df
    column called colname.
    """
    rf.fit(x_train, y)    
    full_zones_df[colname] = rf.predict(x_test)
    print("Results for " + colname + " model:")
    print(full_zones_df[colname].value_counts())
    print()

# %%
run_model(df['HomeZone'].values.reshape(-1, 1), full_zones_df['Origin'].values.reshape(-1, 1), "HZ")
run_model(df.iloc[:, 17:24], full_zones_df.iloc[:, 1:8], "Dists")
# Out:
# Results for HZ model:
# SG    852
# YK    693
# RY    452
# MI    184
# SC    151
# OC     44
# YG     16
# Name: HZ, dtype: int64
#
# Results for Dists model:
# SG    847
# YK    688
# RY    443
# MI    211
# SC    141
# OC     47
# YG     15
# Name: Dists, dtype: int64

# %%
full_zones_df.head()
# Out:
#    Origin   Dist.SG   Dist.SC   Dist.MI   Dist.YK   Dist.YG   Dist.RY  \
# 0       1  8.233101  17.76699  27.43587  24.33012  11.45088  6.407150
# 1       2  7.629588  18.88647  26.70272  23.72661  11.60740  5.773918
# 2       3  6.983658  18.75429  26.05679  23.08068  10.79940  5.127988
# 3       4  6.303398  19.60028  25.34593  22.45217  11.28469  4.417128
# 4       5  5.788057  20.27234  24.83059  21.93682  11.30364  3.901787
#
#     Dist.OC  HZ Dists
# 0  7.172228  RY    RY
# 1  6.420753  RY    RY
# 2  5.774823  RY    RY
# 3  5.063963  RY    RY
# 4  4.548622  RY    SG

# %%
(full_zones_df['HZ'] == full_zones_df['Dists']).value_counts(normalize=True)
# Out:
# True     0.674749
# False    0.325251
# dtype: float64

# %%
temp = full_zones_df[full_zones_df['Origin'] < 4000]
(temp['HZ'] == temp['Dists']).value_counts(normalize=True)
# Out:
# True     0.729099
# False    0.270901
# dtype: float64

# %%
import seaborn as sn
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
sn.heatmap(pd.crosstab(full_zones_df['HZ'], full_zones_df['Dists']), annot=True)
plt.show()

# %%
full_zones_df.to_csv('../Data/SMTO_2015/RF_Predictions.csv', index=False)
