# %%
import biogeme.database as db
import biogeme.biogeme as bio
import biogeme.models as models
from biogeme.expressions import Beta, DefineVariable
import pandas as pd
import math
import csv

df = pd.read_csv('../../Data/SMTO_2015/SMTO_2015_Complete_Input.csv')
school_codes = ['SG', 'SC', 'MI', 'YK','YG', 'RY','OC']
df['School'] = df['School'].apply(lambda x: school_codes.index(x))
#df = df[df['Family'] == 0]
df.head()
# Out:
#                           Campus Level Status  Mode_Actual  Gender  Licence  \
# 0             Scarborough (UTSC)    UG     FT  Transit Bus  Female        0
# 1  Downtown Toronto (St. George)  Grad     FT         Walk  Female        1
# 2  Downtown Toronto (St. George)    UG     FT  Transit Bus  Female        1
# 3  Downtown Toronto (St. George)    UG     FT         Walk    Male        1
# 4  Downtown Toronto (St. George)  Grad     FT         Walk    Male        1
#
#       Work  Age  HomeZone  Family  ...  Admission_Avg.MI  Admission_Avg.YK  \
# 0  Unknown   20       261       1  ...              0.83             0.817
# 1  Unknown   25        71       0  ...              0.83             0.817
# 2  Unknown   23      3714       1  ...              0.83             0.817
# 3  Unknown   20        74       0  ...              0.83             0.817
# 4  Unknown   27        71       0  ...              0.83             0.817
#
# ...

# %%
# Load data into Biogeme database
database = db.Database("SMTO", df.select_dtypes(include = 'number'))
                       
# Definition of new variables: adding columns to the database 
Available =  DefineVariable('Available', 1, database) # All modes available to all students

# Make variable names global
globals().update(database.variables)

# Remove unknown values
#database.remove(Dist == 0.0)
#database.remove(TPTT == 0.0)
#database.remove(AIVTT == 0.0)
# Out:
# C:\Anaconda\lib\site-packages\biogeme\database.py:491: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.data[column] = self.data.apply(functionToApply,axis=1)

# %%
database.data
# Out:
#        Licence  Age  HomeZone  Family  Cars  Children  Adults  School  \
# 0            0   20       261       1     1         3       4       1
# 1            1   25        71       0     0         0       2       0
# 2            1   23      3714       1     1         0       4       0
# 3            1   20        74       0     0         0       4       0
# 4            1   27        71       0     0         0       2       0
# 5            0   20        72       0     0         0       3       0
# 6            0   18       600       1     2         1       4       1
# 7            1   21      3420       1     2         0       5       1
# 8            1   33       113       0     1         0       2       0
# 9            1   31      1031       0     1         0       2       0
# 10           1   21       237       1     1         0       3       0
# 11           1   27        46       0     0         0       2       0
# ...

# %%
ASCs = []
V = {}
av = {}
B_DIST = Beta('B_DIST', -0.5, None, None, 0)
B_ENROLL = Beta('B_ENROLL', 1, None, None, 1)
B_FAM_DIST = Beta('B_FAM_DIST', -0.005, None, None, 0)

for i in range(len(school_codes)):
    code = school_codes[i]
    ASCs.append(Beta('ASC_' + code, 0, None, None, 0 if code != 'SG' else 1))
    #ASCs.append(Beta('ASC_' + code, 0, None, None, 1))
    V[i] = ASCs[i] + B_ENROLL *  database.variables["Total." + code] + B_DIST * database.variables['Dist.' + code] + B_FAM_DIST * database.variables["Dist." + code] * database.variables["Family"]
    av[i] = 1

# %%
school_codes
# Out:
# ['SG', 'SC', 'MI', 'YK', 'YG', 'RY', 'OC']

# %%
V
# Out:
# {0: (((ASC_SG(0) + (B_ENROLL(1) * Total.SG)) + (B_DIST(-0.5) * Dist.SG)) + ((B_FAM_DIST(-0.005) * Dist.SG) * Family)),
#  1: (((ASC_SC(0) + (B_ENROLL(1) * Total.SC)) + (B_DIST(-0.5) * Dist.SC)) + ((B_FAM_DIST(-0.005) * Dist.SC) * Family)),
#  2: (((ASC_MI(0) + (B_ENROLL(1) * Total.MI)) + (B_DIST(-0.5) * Dist.MI)) + ((B_FAM_DIST(-0.005) * Dist.MI) * Family)),
#  3: (((ASC_YK(0) + (B_ENROLL(1) * Total.YK)) + (B_DIST(-0.5) * Dist.YK)) + ((B_FAM_DIST(-0.005) * Dist.YK) * Family)),
#  4: (((ASC_YG(0) + (B_ENROLL(1) * Total.YG)) + (B_DIST(-0.5) * Dist.YG)) + ((B_FAM_DIST(-0.005) * Dist.YG) * Family)),
#  5: (((ASC_RY(0) + (B_ENROLL(1) * Total.RY)) + (B_DIST(-0.5) * Dist.RY)) + ((B_FAM_DIST(-0.005) * Dist.RY) * Family)),
#  6: (((ASC_OC(0) + (B_ENROLL(1) * Total.OC)) + (B_DIST(-0.5) * Dist.OC)) + ((B_FAM_DIST(-0.005) * Dist.OC) * Family))}

# %%
database.data
# Out:
#        Licence  Age  HomeZone  Family  Cars  Children  Adults  School  \
# 0            0   20       261       1     1         3       4       1
# 1            1   25        71       0     0         0       2       0
# 2            1   23      3714       1     1         0       4       0
# 3            1   20        74       0     0         0       4       0
# 4            1   27        71       0     0         0       2       0
# 5            0   20        72       0     0         0       3       0
# 6            0   18       600       1     2         1       4       1
# 7            1   21      3420       1     2         0       5       1
# 8            1   33       113       0     1         0       2       0
# 9            1   31      1031       0     1         0       2       0
# 10           1   21       237       1     1         0       3       0
# 11           1   27        46       0     0         0       2       0
# ...

# %%
# Definition of the model. This is the contribution of each
# observation to the log likelihood function.
logprob = models.loglogit(V, av, School)

# Define level of verbosity
import biogeme.messaging as msg
logger = msg.bioMessage()
logger.setDebug()
#logger.setWarning()
#logger.setGeneral()
#logger.setDetailed()

# Create the Biogeme object
biogeme  = bio.BIOGEME(database,logprob,numberOfThreads=1)
biogeme.modelName = "SMTO_2015_Logit_Campus_Choice"
#,numberOfThreads=1

# Estimate the parameters
results = biogeme.estimate(saveIterations=True)
biogeme.createLogFile()

# Print the estimated values
betas = results.getBetaValues()
for k,v in betas.items():
    print(f"{k:10}=\t{v:.3g}")

# Get the results in a pandas table
pandasResults = results.getEstimatedParameters()
print(pandasResults)
# Out:
# [13:39:32] < General >   Remove 69 unused variables from the database as only 16 are used.
# [13:39:32] < General >   Log likelihood (N=14782):  -47910.23
# [13:39:32] < General >   Minimize with tol 1e-07
# [13:39:33] < Debug >     ASC_MI:          0
# [13:39:33] < Debug >     ASC_OC:          0
# [13:39:33] < Debug >     ASC_RY:          0
# [13:39:33] < Debug >     ASC_SC:          0
# [13:39:33] < Debug >     ASC_YG:          0
# [13:39:33] < Debug >     ASC_YK:          0
# [13:39:33] < Debug >     B_DIST:       -0.5
# [13:39:33] < Debug >     B_FAM_DIST:     -0.005
# [13:39:33] < General >   Log likelihood (N=14782):  -47910.23 Gradient norm:      1e+05
# [13:39:33] < Debug >     ASC_MI: -0.01480656
# [13:39:33] < Debug >     ASC_OC: 0.001966841
# [13:39:33] < Debug >     ASC_RY: 0.008107097
# [13:39:33] < Debug >     ASC_SC: -0.008915049
# [13:39:33] < Debug >     ASC_YG: -0.001294428
# [13:39:33] < Debug >     ASC_YK: -0.001057773
# ...

# %%
# Generate probabilities
betas
# Out:
# {'ASC_MI': -0.20005244673814168,
#  'ASC_OC': 0.2104919275725693,
#  'ASC_RY': -0.04767405900706797,
#  'ASC_SC': 0.22937345591154595,
#  'ASC_YG': 0.42316387974370234,
#  'ASC_YK': -0.11353440146674226,
#  'B_DIST': -0.13767327091391085,
#  'B_FAM_DIST': 0.07244202672826623}

# %%
for i in range(len(school_codes)):
    code = school_codes[i]
    df['V_'+ code] = (betas['ASC_' + code] if code != 'SG' else 0) + betas['B_DIST'] * df['Dist.' + code] + betas['B_FAM_DIST'] * df['Dist.' + code] * df['Family'] + df['Total.' + code]

# %%
utils = df.iloc[:,-7:]
for i in range(len(school_codes)):
    code = school_codes[i]
    df['P_' + code] = utils.apply(lambda x: math.exp(x['V_' + code]) / sum([math.exp(j) for j in x]), axis = 1)

# %%
probs = df.iloc[:,-7:]
probs = pd.concat((df['School'], probs), axis = 1)

# %%
for school in range(len(school_codes)):
        # Soft-Max
        #print(*probs[probs['School'] == school][['P_' + i for i in school_codes]].sum().values)
        # Hard - Max
        print(*probs[probs['School'] == school][['P_' + i for i in school_codes]].idxmax(axis = 1).value_counts())
# Out:
# 4795 869 245 77
# 460 397 223 1
# 569 192 169 8
# 1579 1330 163 50
# 201 93 28 4
# 1876 762 202 31
# 329 94 28 7

# %%
print(utils.mean())
# Out:
# V_SG    9.500630
# V_SC    6.982585
# V_MI    6.880505
# V_YK    8.588604
# V_YG    6.486196
# V_RY    8.760277
# V_OC    6.923284
# dtype: float64

# %%
print(*school_codes)
# Out:
# SG SC MI YK YG RY OC
