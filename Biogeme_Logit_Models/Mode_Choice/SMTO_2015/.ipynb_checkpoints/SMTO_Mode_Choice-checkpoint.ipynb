# %% [markdown]
# # Biogeme Test - SMTO Data
#
# Gonna try to adapt the Biogeme Swissmetro example to university choice using SMTO data set. We'll try to predict __mode__ choice using distance.

# %%
import biogeme.database as db
import biogeme.biogeme as bio
import biogeme.models as models
from biogeme.expressions import Beta, DefineVariable
import pandas as pd

hh_df = pd.read_csv('../../Data/SMTO_2015/SMTO_2015_Households.csv')
ps_df = pd.read_csv('../../Data/SMTO_2015/SMTO_2015_Respondents.csv')

# %%
# Load relevant columns
df = ps_df[['pscampusattend']]
df = df.join(hh_df[['HmTTS2006']])
df = df.join(ps_df[['psmainmodefalltypical']])
df = df.rename(columns={'HmTTS2006': 'HomeZone', 'pscampusattend': 'Campus', 'psmainmodefalltypical': 'Mode'})
df = df.dropna() # Remove rows with missing data

# Convert Campus and Mode column to numerical column
campus_name_to_num = {"Downtown Toronto (St. George)": 0, "Scarborough (UTSC)": 1, "Mississauga (UTM)": 2,
                      "Keele": 3, "Glendon": 4, "RyersonU": 5, "OCADu": 6}
mode_name_to_num = {"Car - Driver alone": 0, "Car - Driver with passenger(s)": 0, "Car - Passenger": 0, "Taxi": 0, "Transit Bus": 1, "Streetcar": 1, "Subway/RT": 1, "GO Bus": 1, "GO Train": 1, "Walk": 2, "Bicycle": 2}

df.replace({'Campus': campus_name_to_num}, inplace=True)
df.replace({'Mode': mode_name_to_num}, inplace=True)
print(df.shape)
# Remove "Other" Modes
df = df[(df['Mode'] == 0) | (df['Mode'] == 1) | (df['Mode'] == 2)]
print(df.shape)
df['HomeZone'] = pd.to_numeric(df['HomeZone'], downcast='signed')
df['Mode'] = pd.to_numeric(df['Mode'], downcast='signed')

df.head()
# Out:
# (15064, 3)
# (14915, 3)
#    Campus  HomeZone  Mode
# 0       1       261     1
# 1       0        71     2
# 2       0      3714     1
# 3       0        74     2
# 4       0        71     2

# %%
# Dataframe with walk distances
df_path = pd.read_csv('../../../LoS/Walk_Distances.csv')
origins = list(set(list(df_path['Origin'])))
dists = list(df_path['Data'])

# %%
# Dataframe with AutoTravelTimes
df_att = pd.read_csv('../../../LoS/Auto_Travel_Times.csv')
AutoTravelTimes = list(df_att['Data'])

# %%
# Dataframe with TransitTravelTimes
df_ttt = pd.read_csv('../../../LoS/Transit_Travel_Times.csv')
TransitTravelTimes = list(df_ttt['Data'])

# %%
not_found = set()
# Function for distance/AutoTravelTime/TransitTravelTime lookup

def find_value(origin, destination, mode_num):
    # mode_num: 0 - to find AutoTravelTime
    #           1 - to find TransitTravelTime
    #           2 - to find Walking Distance
    #
    try:
        i = origins.index(origin)
    except ValueError:
        not_found.add(origin)
        return 0
    try:
        j = origins.index(destination)
    except ValueError:
        not_found.add(destination)
        return 0
    
    if mode_num == 0:
        return AutoTravelTimes[i*2392 + j]
    elif mode_num == 1:
        return TransitTravelTimes[i*2392 + j]
    elif mode_num == 2:
        return dists[i*2392 + j] / 1000
    else:
        print("ERROR: Enter correct mode_num!")
        return 0

# %%
# List of campus' TTS zones from Joven's MOE data
campus_zones = [69, 566, 3631, 391, 225, 38, 67]

# Add column with campus zones
df['CampusZone'] = df['Campus'].apply(lambda x: campus_zones[x])

# Add columns for Distance, Transit Travel Time, Auto Travel Time
df['AIVTT'] = df.apply(lambda x: find_value(x.HomeZone, x.CampusZone, 0), axis=1)
df['TPTT'] = df.apply(lambda x: find_value(x.HomeZone, x.CampusZone, 1), axis=1)
df['Dist'] = df.apply(lambda x: find_value(x.HomeZone, x.CampusZone, 2), axis=1)

# %%
df.head()
# Out:
#    Campus  HomeZone  Mode  CampusZone      AIVTT        TPTT       Dist
# 0       1       261     1         566  17.474220   75.468478  14.880980
# 1       0        71     2          69   2.924953   24.128386   1.132351
# 2       0      3714     1          69  50.171880  155.551170  23.319230
# 3       0        74     2          69   1.049121   16.675728   0.699414
# 4       0        71     2          69   2.924953   24.128386   1.132351

# %%
# Load data into Biogeme database
database = db.Database("SMTO", df)

# Definition of new variables: adding columns to the database 
Available =  DefineVariable('Available', 1, database) # All modes available to all students

# Make variable names global
globals().update(database.variables)

# Remove unknown values
database.remove(Dist == 0.0)
database.remove(TPTT == 0.0)
database.remove(AIVTT == 0.0)

# %%
df.head()
# Out:
#    Campus  HomeZone  Mode  CampusZone      AIVTT        TPTT       Dist  \
# 0       1       261     1         566  17.474220   75.468478  14.880980
# 1       0        71     2          69   2.924953   24.128386   1.132351
# 2       0      3714     1          69  50.171880  155.551170  23.319230
# 3       0        74     2          69   1.049121   16.675728   0.699414
# 4       0        71     2          69   2.924953   24.128386   1.132351
#
#    Available
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %%
#df.to_csv('../../../../../../../ModeChoice_Input.csv', index=False)

# %%
"""
# Here we use the "biogeme" way for backward compatibility
exclude = HomeToMainCampusKM > 130
database.remove(exclude)
database.data

# Parameters to be estimated
ASC_CAR = Beta('ASC_CAR',0,None,None,0)
ASC_TRAIN = Beta('ASC_TRAIN',0,None,None,0)
ASC_SM = Beta('ASC_SM',0,None,None,1)
B_TIME = Beta('B_TIME',0,None,None,0)
B_COST = Beta('B_COST',0,None,None,0)

# Definition of new variables
SM_COST =  SM_CO   * (  GA   ==  0  ) 
TRAIN_COST =  TRAIN_CO   * (  GA   ==  0  )

# Definition of new variables: adding columns to the database 
CAR_AV_SP =  DefineVariable('CAR_AV_SP',CAR_AV  * (  SP   !=  0  ),database)
TRAIN_AV_SP =  DefineVariable('TRAIN_AV_SP',TRAIN_AV  * (  SP   !=  0  ),database)
TRAIN_TT_SCALED = DefineVariable('TRAIN_TT_SCALED',\
                                 TRAIN_TT / 100.0,database)
TRAIN_COST_SCALED = DefineVariable('TRAIN_COST_SCALED',\
                                   TRAIN_COST / 100,database)
SM_TT_SCALED = DefineVariable('SM_TT_SCALED', SM_TT / 100.0,database)
SM_COST_SCALED = DefineVariable('SM_COST_SCALED', SM_COST / 100,database)
CAR_TT_SCALED = DefineVariable('CAR_TT_SCALED', CAR_TT / 100,database)
CAR_CO_SCALED = DefineVariable('CAR_CO_SCALED', CAR_CO / 100,database)

# Definition of the utility functions
V1 = ASC_TRAIN + \
     B_TIME * TRAIN_TT_SCALED + \
     B_COST * TRAIN_COST_SCALED
V2 = ASC_SM + \
     B_TIME * SM_TT_SCALED + \
     B_COST * SM_COST_SCALED
V3 = ASC_CAR + \
     B_TIME * CAR_TT_SCALED + \
     B_COST * CAR_CO_SCALED

# Associate utility functions with the numbering of alternatives
V = {1: V1,
     2: V2,
     3: V3}

# Associate the availability conditions with the alternatives
av = {1: TRAIN_AV_SP,
      2: SM_AV,
      3: CAR_AV_SP}
      
# Definition of the model. This is the contribution of each
# observation to the log likelihood function.
logprob = models.loglogit(V,av,CHOICE)

"""


# Beta initialization: (name, value, lowerbound, upperbound, status, desc='')
# Status 0 if estimated, 1 if maintained - reference choice should be 1
ASC_AU = Beta('ASC_AU', 0, None, None, 1)
ASC_TR = Beta('ASC_TR', 0, None, None, 0)
ASC_AC = Beta('ASC_AC', 0, None, None, 0)
B_AIVTT = Beta('B_AIVTT', -0.05, None, None, 0)
B_TPTT = Beta('B_TPTT', -0.05, None, None, 0)
B_DIST = Beta('B_DIST', -0.0005, None, None, 0)


# Variables: from columns in database
AV = DefineVariable('AV', Available, database)
AU_AIVTT = DefineVariable('AU_AIVTT', AIVTT, database)
TR_TPTT = DefineVariable('TR_TPTT', TPTT, database)
AC_DIST = DefineVariable('AC_DIST', Dist, database)

# Mode Choice Utility Functions: ASC_AU is 0
V0 = ASC_AU + B_AIVTT * AU_AIVTT
V1 = ASC_TR + B_TPTT * TR_TPTT
V2 = ASC_AC + B_DIST * AC_DIST


V  = {0: V0, 1: V1, 2: V2}
av = {0: AV, 1: AV, 2: AV}

# %%
database.data
# Out:
#        Campus  HomeZone  Mode  CampusZone      AIVTT        TPTT       Dist  \
# 0           1       261     1         566  17.474220   75.468478  14.880980
# 1           0        71     2          69   2.924953   24.128386   1.132351
# 2           0      3714     1          69  50.171880  155.551170  23.319230
# 3           0        74     2          69   1.049121   16.675728   0.699414
# 4           0        71     2          69   2.924953   24.128386   1.132351
# 5           0        72     2          69   3.068723   25.742024   1.595176
# 6           1       600     1         566  14.542720   53.745301  11.499560
# 7           1      3420     0         566  60.657420  213.667410  46.280060
# 8           0       113     2          69  15.759180   42.637287   6.260033
# 9           0      1031     1          69  66.121790  117.968371  29.734180
# 10          0       237     1          69  26.741290   79.651417  12.272810
# 11          0        46     2          69   2.168042   23.855996   1.297744
# 12          0       472     1          69  42.485580  133.416563  20.411940
# 13          0        50     2          69   2.595157   27.402340   1.587002
# 14          0        21     2          69   4.289724   29.348300   2.044520
# 15          0       209     1          69  10.911490   42.701539   4.886681
# 17          0        22     2          69   4.372437   25.162232   2.096960
# 18          0       554     1          69  45.030450   94.027575  18.765190
# 19          0        38     1          69   3.320328   31.447038   1.916098
# 20          2      3868     1        3631  38.668560  121.874450  24.910890
# 21          0        67     2          69   2.523888   24.493027   1.897934
# 22          1      1042     1         566  32.800550  110.676591  19.472390
# 23          0      2081     1          69  56.115770  106.759166  24.502110
# 24          0       480     1          69  40.692500  116.478907  19.304530
# 25          0       413     2          69  32.902340   68.344045  14.209780
# 26          0       542     2          69  31.103580   71.911254  11.824900
# 27          0        51     2          69   2.071490   24.722109   1.268754
# 28          0        71     2          69   2.924953   24.128386   1.132351
# 29          2      3664     1        3631  23.790200   98.938800  13.644540
# 30          0        67     2          69   2.523888   24.493027   1.897934
# ...       ...       ...   ...         ...        ...         ...        ...
# 15194       3      3665     1         391  51.779350  115.300704  33.410220
# 15195       3      2405     1         391  32.011940   86.540719  23.322120
# 15196       3       257     2         391  42.639490  186.947686  23.413960
# 15197       3       411     1         391   7.508195   48.138369   5.561901
# 15198       3       129     1         391  19.789250   73.647332  13.013310
# 15199       3       568     1         391  51.010140  229.805770  31.631830
# 15200       3       472     1         391  23.688670  100.623299  12.685710
# 15201       3      3386     1         391  46.768210  159.474286  29.484900
# 15202       3       412     1         391   4.613157   28.897975   3.219461
# 15203       3      3369     1         391  31.142130  138.722029  18.870000
# 15204       3      3334     1         391  51.466880  150.564320  32.498460
# 15205       3      3617     1         391  41.070520   96.530542  27.017130
# 15206       3      3376     1         391  55.698330  125.538100  32.813340
# 15207       3       384     1         391  15.691430   65.465105   7.910512
# 15208       3        50     1         391  29.007420  153.867933  18.043510
# 15209       3       232     1         391  27.525290  105.806146  16.225560
# 15210       3       409     1         391  10.282660   49.678664   7.127491
# 15212       3      2659     1         391  52.625600  114.527280  36.710110
# 15213       3       399     2         391   3.391024   25.457970   2.590368
# 15214       3      3630     1         391  40.258000   92.397530  26.993020
# 15215       4       571     1         225  36.671630  123.102131  20.187700
# 15216       3      2072     0         391  21.627530   78.868449   9.253344
# 15217       3      2216     1         391  31.689090  110.001346  16.889960
# 15219       3       398     2         391   2.528039   22.375469   1.773034
# 15220       4       472     1         225  19.215900   62.177829  10.250680
# 15221       3       212     1         391  23.204610   86.132227  14.195300
# 15222       3       233     1         391  30.347150  108.974238  17.687720
# 15223       3        95     1         391  24.507190  156.081511  15.536000
# 15224       3      2221     1         391  20.865730   78.879473  13.304580
# 15225       3      3686     1         391  39.526000  103.837317  34.806510
#
#        Available   AV   AU_AIVTT     TR_TPTT    AC_DIST
# 0              1  1.0  17.474220   75.468478  14.880980
# 1              1  1.0   2.924953   24.128386   1.132351
# 2              1  1.0  50.171880  155.551170  23.319230
# 3              1  1.0   1.049121   16.675728   0.699414
# 4              1  1.0   2.924953   24.128386   1.132351
# 5              1  1.0   3.068723   25.742024   1.595176
# 6              1  1.0  14.542720   53.745301  11.499560
# 7              1  1.0  60.657420  213.667410  46.280060
# 8              1  1.0  15.759180   42.637287   6.260033
# 9              1  1.0  66.121790  117.968371  29.734180
# 10             1  1.0  26.741290   79.651417  12.272810
# 11             1  1.0   2.168042   23.855996   1.297744
# 12             1  1.0  42.485580  133.416563  20.411940
# 13             1  1.0   2.595157   27.402340   1.587002
# 14             1  1.0   4.289724   29.348300   2.044520
# 15             1  1.0  10.911490   42.701539   4.886681
# 17             1  1.0   4.372437   25.162232   2.096960
# 18             1  1.0  45.030450   94.027575  18.765190
# 19             1  1.0   3.320328   31.447038   1.916098
# 20             1  1.0  38.668560  121.874450  24.910890
# 21             1  1.0   2.523888   24.493027   1.897934
# 22             1  1.0  32.800550  110.676591  19.472390
# 23             1  1.0  56.115770  106.759166  24.502110
# 24             1  1.0  40.692500  116.478907  19.304530
# 25             1  1.0  32.902340   68.344045  14.209780
# 26             1  1.0  31.103580   71.911254  11.824900
# 27             1  1.0   2.071490   24.722109   1.268754
# 28             1  1.0   2.924953   24.128386   1.132351
# 29             1  1.0  23.790200   98.938800  13.644540
# 30             1  1.0   2.523888   24.493027   1.897934
# ...          ...  ...        ...         ...        ...
# 15194          1  1.0  51.779350  115.300704  33.410220
# 15195          1  1.0  32.011940   86.540719  23.322120
# 15196          1  1.0  42.639490  186.947686  23.413960
# 15197          1  1.0   7.508195   48.138369   5.561901
# 15198          1  1.0  19.789250   73.647332  13.013310
# 15199          1  1.0  51.010140  229.805770  31.631830
# 15200          1  1.0  23.688670  100.623299  12.685710
# 15201          1  1.0  46.768210  159.474286  29.484900
# 15202          1  1.0   4.613157   28.897975   3.219461
# 15203          1  1.0  31.142130  138.722029  18.870000
# 15204          1  1.0  51.466880  150.564320  32.498460
# 15205          1  1.0  41.070520   96.530542  27.017130
# 15206          1  1.0  55.698330  125.538100  32.813340
# 15207          1  1.0  15.691430   65.465105   7.910512
# 15208          1  1.0  29.007420  153.867933  18.043510
# 15209          1  1.0  27.525290  105.806146  16.225560
# 15210          1  1.0  10.282660   49.678664   7.127491
# 15212          1  1.0  52.625600  114.527280  36.710110
# 15213          1  1.0   3.391024   25.457970   2.590368
# 15214          1  1.0  40.258000   92.397530  26.993020
# 15215          1  1.0  36.671630  123.102131  20.187700
# 15216          1  1.0  21.627530   78.868449   9.253344
# 15217          1  1.0  31.689090  110.001346  16.889960
# 15219          1  1.0   2.528039   22.375469   1.773034
# 15220          1  1.0  19.215900   62.177829  10.250680
# 15221          1  1.0  23.204610   86.132227  14.195300
# 15222          1  1.0  30.347150  108.974238  17.687720
# 15223          1  1.0  24.507190  156.081511  15.536000
# 15224          1  1.0  20.865730   78.879473  13.304580
# 15225          1  1.0  39.526000  103.837317  34.806510
#
# [14260 rows x 12 columns]

# %%
# Definition of the model. This is the contribution of each
# observation to the log likelihood function.
logprob = models.loglogit(V, av, Mode)

# Define level of verbosity
import biogeme.messaging as msg
logger = msg.bioMessage()
logger.setDebug()
#logger.setWarning()
#logger.setGeneral()
#logger.setDetailed()

# Create the Biogeme object
biogeme  = bio.BIOGEME(database,logprob,numberOfThreads=1)
biogeme.modelName = "SMTO_Logit_ModeChoice_ReRun2"
#,numberOfThreads=1

# Estimate the parameters
results = biogeme.estimate(saveIterations=True)
biogeme.createLogFile()

# Print the estimated values
betas = results.getBetaValues()
for k,v in betas.items():
    print(f"{k:10}=\t{v:.3g}")

# Get the results in a pandas table
pandasResults = results.getEstimatedParameters()
print(pandasResults)
# Out:
# [11:27:42] < General >   Remove 7 unused variables from the database as only 5 are used.
# [11:27:42] < General >   Log likelihood (N=14260):  -54960.48
# [11:27:42] < General >   Minimize with tol 1e-07
# [11:27:42] < Debug >     ASC_AC:          0
# [11:27:42] < Debug >     ASC_TR:          0
# [11:27:42] < Debug >     B_AIVTT:      -0.05
# [11:27:42] < Debug >     B_DIST:    -0.0005
# [11:27:42] < Debug >     B_TPTT:      -0.05
# [11:27:42] < General >   Log likelihood (N=14260):  -54960.48 Gradient norm:      9e+05
# [11:27:43] < Debug >     ASC_AC: -0.007251697
# [11:27:43] < Debug >     ASC_TR: 0.009263545
# [11:27:43] < Debug >     B_AIVTT: -0.05002275
# [11:27:43] < Debug >     B_DIST: -0.1983296
# [11:27:43] < Debug >     B_TPTT:  0.9301658
# [11:27:43] < General >   Log likelihood (N=14260):  -235634.9 Gradient norm:      3e+05
# [11:27:43] < Debug >     ASC_AC: -0.001948298
# [11:27:43] < Debug >     ASC_TR: 0.002488817
# [11:27:43] < Debug >     B_AIVTT: -0.05000611
# [11:27:43] < Debug >     B_DIST: -0.05365046
# [11:27:43] < Debug >     B_TPTT:  0.2133391
# [11:27:43] < General >   Log likelihood (N=14260):  -56031.81 Gradient norm:      3e+05
# [11:27:43] < Debug >     ASC_AC: -0.0007314757
# [11:27:43] < Debug >     ASC_TR: 0.00093441
# [11:27:43] < Debug >     B_AIVTT: -0.05000229
# [11:27:43] < Debug >     B_DIST: -0.02045499
# [11:27:43] < Debug >     B_TPTT: 0.04886893
# [11:27:43] < General >   Log likelihood (N=14260):  -16721.79 Gradient norm:      2e+05
# [11:27:43] < Debug >     ASC_AC: -0.0005246815
# [11:27:43] < Debug >     ASC_TR: 0.000676471
# [11:27:43] < Debug >     B_AIVTT: -0.04674424
# [11:27:43] < Debug >     B_DIST: -0.0194474
# [11:27:43] < Debug >     B_TPTT: 0.03163229
# [11:27:43] < General >   Log likelihood (N=14260):  -13472.68 Gradient norm:      2e+05
# [11:27:43] < Debug >     ASC_AC: 0.0002592686
# [11:27:43] < Debug >     ASC_TR: 9.852078e-05
# [11:27:43] < Debug >     B_AIVTT: -0.02347919
# [11:27:43] < Debug >     B_DIST: -0.02149314
# [11:27:43] < Debug >     B_TPTT: -0.03193356
# [11:27:43] < General >   Log likelihood (N=14260):  -35999.34 Gradient norm:      9e+05
# [11:27:43] < Debug >     ASC_AC: -0.0003932434
# [11:27:43] < Debug >     ASC_TR: 0.0005795711
# [11:27:43] < Debug >     B_AIVTT: -0.04284359
# [11:27:43] < Debug >     B_DIST: -0.01979039
# [11:27:43] < Debug >     B_TPTT: 0.02097476
# [11:27:43] < General >   Log likelihood (N=14260):  -11945.88 Gradient norm:      1e+05
# [11:27:43] < Debug >     ASC_AC: -6.826739e-05
# [11:27:43] < Debug >     ASC_TR: 0.0004401999
# [11:27:43] < Debug >     B_AIVTT: -0.03058931
# [11:27:43] < Debug >     B_DIST: -0.02376382
# [11:27:43] < Debug >     B_TPTT: 0.002181987
# [11:27:43] < General >   Log likelihood (N=14260):  -12218.95 Gradient norm:      2e+05
# [11:27:43] < Debug >     ASC_AC: -0.0002369381
# [11:27:43] < Debug >     ASC_TR: 0.0005125371
# [11:27:43] < Debug >     B_AIVTT: -0.03694959
# [11:27:43] < Debug >     B_DIST: -0.02170151
# [11:27:43] < Debug >     B_TPTT: 0.01193591
# [11:27:43] < General >   Log likelihood (N=14260):  -11292.37 Gradient norm:      3e+04
# [11:27:43] < Debug >     ASC_AC: -0.0001411064
# [11:27:43] < Debug >     ASC_TR: 0.0004958107
# [11:27:43] < Debug >     B_AIVTT: -0.03307906
# [11:27:43] < Debug >     B_DIST: -0.02404141
# [11:27:43] < Debug >     B_TPTT: 0.01102078
# [11:27:43] < General >   Log likelihood (N=14260):   -11174.3 Gradient norm:      4e+04
# [11:27:43] < Debug >     ASC_AC: 0.000568448
# [11:27:43] < Debug >     ASC_TR: 0.0003963412
# [11:27:43] < Debug >     B_AIVTT: -0.007303731
# [11:27:43] < Debug >     B_DIST: -0.04098386
# [11:27:43] < Debug >     B_TPTT: 0.01051928
# [11:27:43] < General >   Log likelihood (N=14260):  -10814.72 Gradient norm:      8e+04
# [11:27:43] < Debug >     ASC_AC: 0.0007558882
# [11:27:43] < Debug >     ASC_TR: 0.0003610566
# [11:27:43] < Debug >     B_AIVTT: -0.01087799
# [11:27:43] < Debug >     B_DIST: -0.04038587
# [11:27:43] < Debug >     B_TPTT:    0.01356
# [11:27:43] < General >   Log likelihood (N=14260):  -10657.54 Gradient norm:      1e+04
# [11:27:43] < Debug >     ASC_AC: 0.00103847
# [11:27:43] < Debug >     ASC_TR: 0.0003228208
# [11:27:43] < Debug >     B_AIVTT: -0.006425818
# [11:27:43] < Debug >     B_DIST: -0.04421225
# [11:27:43] < Debug >     B_TPTT: 0.01500427
# [11:27:43] < General >   Log likelihood (N=14260):  -10622.14 Gradient norm:      5e+03
# [11:27:43] < Debug >     ASC_AC: 0.001648148
# [11:27:43] < Debug >     ASC_TR: 0.0002369099
# [11:27:43] < Debug >     B_AIVTT: -0.00452384
# [11:27:43] < Debug >     B_DIST: -0.04753211
# [11:27:43] < Debug >     B_TPTT:  0.0154958
# [11:27:43] < General >   Log likelihood (N=14260):  -10609.95 Gradient norm:      5e+03
# [11:27:43] < Debug >     ASC_AC: 0.003576549
# [11:27:43] < Debug >     ASC_TR: -3.637649e-05
# [11:27:43] < Debug >     B_AIVTT: -0.004256804
# [11:27:43] < Debug >     B_DIST: -0.05439745
# [11:27:43] < Debug >     B_TPTT: 0.01543276
# [11:27:43] < General >   Log likelihood (N=14260):  -10586.04 Gradient norm:      6e+03
# [11:27:43] < Debug >     ASC_AC: 0.01244889
# [11:27:43] < Debug >     ASC_TR: -0.001282386
# [11:27:43] < Debug >     B_AIVTT: -0.008400101
# [11:27:43] < Debug >     B_DIST: -0.08197294
# [11:27:43] < Debug >     B_TPTT: 0.01352655
# [11:27:43] < General >   Log likelihood (N=14260):  -10503.22 Gradient norm:      1e+04
# [11:27:43] < Debug >     ASC_AC: 0.02916773
# [11:27:43] < Debug >     ASC_TR: -0.003532927
# [11:27:43] < Debug >     B_AIVTT: -0.02083347
# [11:27:43] < Debug >     B_DIST: -0.1265998
# [11:27:43] < Debug >     B_TPTT: 0.008627498
# [11:27:43] < General >   Log likelihood (N=14260):  -10397.09 Gradient norm:      9e+03
# [11:27:43] < Debug >     ASC_AC: 0.06006281
# [11:27:43] < Debug >     ASC_TR: -0.006647672
# [11:27:43] < Debug >     B_AIVTT: -0.03687846
# [11:27:43] < Debug >     B_DIST: -0.1654821
# [11:27:43] < Debug >     B_TPTT: 0.003000145
# [11:27:43] < General >   Log likelihood (N=14260):  -10310.78 Gradient norm:      4e+03
# [11:27:43] < Debug >     ASC_AC: 0.08803282
# [11:27:43] < Debug >     ASC_TR: -0.009124301
# [11:27:43] < Debug >     B_AIVTT: -0.04905402
# [11:27:43] < Debug >     B_DIST: -0.1862676
# [11:27:43] < Debug >     B_TPTT: -0.0006585665
# [11:27:43] < General >   Log likelihood (N=14260):  -10271.64 Gradient norm:      3e+03
# [11:27:43] < Debug >     ASC_AC:  0.1129567
# [11:27:43] < Debug >     ASC_TR: -0.01100367
# [11:27:43] < Debug >     B_AIVTT: -0.05555215
# [11:27:43] < Debug >     B_DIST:   -0.19236
# [11:27:43] < Debug >     B_TPTT: -0.002223834
# [11:27:43] < General >   Log likelihood (N=14260):  -10245.06 Gradient norm:      3e+03
# [11:27:43] < Debug >     ASC_AC:  0.1649061
# [11:27:43] < Debug >     ASC_TR: -0.01460569
# [11:27:43] < Debug >     B_AIVTT: -0.06295802
# [11:27:43] < Debug >     B_DIST: -0.1965085
# [11:27:43] < Debug >     B_TPTT: -0.003998982
# [11:27:43] < General >   Log likelihood (N=14260):  -10198.71 Gradient norm:      7e+03
# [11:27:43] < Debug >     ASC_AC:  0.2568294
# [11:27:43] < Debug >     ASC_TR: -0.02068099
# [11:27:43] < Debug >     B_AIVTT: -0.06891148
# [11:27:43] < Debug >     B_DIST: -0.1981888
# [11:27:43] < Debug >     B_TPTT: -0.005076881
# [11:27:43] < General >   Log likelihood (N=14260):  -10120.89 Gradient norm:      1e+04
# [11:27:43] < Debug >     ASC_AC:  0.4849113
# [11:27:43] < Debug >     ASC_TR: -0.03559982
# [11:27:43] < Debug >     B_AIVTT: -0.07405611
# [11:27:43] < Debug >     B_DIST: -0.2082516
# [11:27:43] < Debug >     B_TPTT: -0.007877732
# [11:27:43] < General >   Log likelihood (N=14260):  -9971.675 Gradient norm:      4e+04
# [11:27:43] < Debug >     ASC_AC:  0.8555349
# [11:27:43] < Debug >     ASC_TR: -0.05923399
# [11:27:43] < Debug >     B_AIVTT: -0.07288674
# [11:27:43] < Debug >     B_DIST: -0.2108281
# [11:27:43] < Debug >     B_TPTT: -0.004344931
# [11:27:43] < General >   Log likelihood (N=14260):  -9668.733 Gradient norm:      3e+04
# [11:27:43] < Debug >     ASC_AC:   1.491798
# [11:27:43] < Debug >     ASC_TR: -0.09926087
# [11:27:43] < Debug >     B_AIVTT: -0.0459544
# [11:27:43] < Debug >     B_DIST: -0.2204081
# [11:27:43] < Debug >     B_TPTT: 0.003218225
# [11:27:43] < General >   Log likelihood (N=14260):  -9091.914 Gradient norm:      3e+04
# [11:27:43] < Debug >     ASC_AC:   2.403302
# [11:27:43] < Debug >     ASC_TR: -0.1573156
# [11:27:43] < Debug >     B_AIVTT: -0.05319187
# [11:27:43] < Debug >     B_DIST: -0.3875964
# [11:27:43] < Debug >     B_TPTT: 0.008739543
# [11:27:43] < General >   Log likelihood (N=14260):  -8917.138 Gradient norm:      6e+04
# [11:27:43] < Debug >     ASC_AC:   2.487551
# [11:27:43] < Debug >     ASC_TR: -0.1609923
# [11:27:43] < Debug >     B_AIVTT: -0.008567933
# [11:27:43] < Debug >     B_DIST: -0.3350019
# [11:27:43] < Debug >     B_TPTT: 0.01595041
# [11:27:43] < General >   Log likelihood (N=14260):  -8507.855 Gradient norm:      4e+03
# [11:27:43] < Debug >     ASC_AC:   2.417904
# [11:27:43] < Debug >     ASC_TR: -0.1565286
# [11:27:43] < Debug >     B_AIVTT: -0.01169037
# [11:27:43] < Debug >     B_DIST: -0.3492368
# [11:27:43] < Debug >     B_TPTT: 0.01488784
# [11:27:43] < General >   Log likelihood (N=14260):  -8482.701 Gradient norm:      3e+03
# [11:27:43] < Debug >     ASC_AC:    2.40373
# [11:27:43] < Debug >     ASC_TR: -0.1550333
# [11:27:43] < Debug >     B_AIVTT: -0.01199926
# [11:27:43] < Debug >     B_DIST: -0.3767969
# [11:27:43] < Debug >     B_TPTT: 0.01406425
# [11:27:43] < General >   Log likelihood (N=14260):  -8466.631 Gradient norm:      2e+03
# [11:27:43] < Debug >     ASC_AC:   2.455553
# [11:27:43] < Debug >     ASC_TR: -0.1572859
# [11:27:43] < Debug >     B_AIVTT: -0.01520987
# [11:27:43] < Debug >     B_DIST: -0.3964035
# [11:27:43] < Debug >     B_TPTT: 0.01328003
# [11:27:43] < General >   Log likelihood (N=14260):  -8462.872 Gradient norm:      3e+03
# [11:27:43] < Debug >     ASC_AC:   2.498955
# [11:27:43] < Debug >     ASC_TR: -0.1593377
# [11:27:43] < Debug >     B_AIVTT: -0.01504396
# [11:27:43] < Debug >     B_DIST: -0.4043478
# [11:27:43] < Debug >     B_TPTT: 0.01322087
# [11:27:43] < General >   Log likelihood (N=14260):  -8461.783 Gradient norm:      1e+03
# [11:27:43] < Debug >     ASC_AC:   2.518552
# [11:27:43] < Debug >     ASC_TR: -0.1598398
# [11:27:43] < Debug >     B_AIVTT: -0.01506416
# [11:27:43] < Debug >     B_DIST: -0.4074453
# [11:27:43] < Debug >     B_TPTT: 0.01313125
# [11:27:43] < General >   Log likelihood (N=14260):  -8461.326 Gradient norm:      7e+02
# [11:27:43] < Debug >     ASC_AC:    2.53691
# [11:27:43] < Debug >     ASC_TR: -0.1594848
# [11:27:43] < Debug >     B_AIVTT: -0.0153344
# [11:27:43] < Debug >     B_DIST: -0.4104813
# [11:27:43] < Debug >     B_TPTT: 0.01291586
# [11:27:43] < General >   Log likelihood (N=14260):  -8460.653 Gradient norm:      2e+03
# [11:27:43] < Debug >     ASC_AC:   2.554743
# [11:27:43] < Debug >     ASC_TR: -0.1573348
# [11:27:43] < Debug >     B_AIVTT: -0.01591395
# [11:27:43] < Debug >     B_DIST: -0.4137109
# [11:27:43] < Debug >     B_TPTT: 0.01253532
# [11:27:43] < General >   Log likelihood (N=14260):  -8459.375 Gradient norm:      4e+03
# [11:27:43] < Debug >     ASC_AC:   2.576522
# [11:27:43] < Debug >     ASC_TR:  -0.150233
# [11:27:43] < Debug >     B_AIVTT: -0.01707151
# [11:27:43] < Debug >     B_DIST: -0.4179952
# [11:27:43] < Debug >     B_TPTT: 0.01181443
# [11:27:43] < General >   Log likelihood (N=14260):  -8456.266 Gradient norm:      7e+03
# [11:27:44] < Debug >     ASC_AC:   2.603261
# [11:27:44] < Debug >     ASC_TR: -0.1309094
# [11:27:44] < Debug >     B_AIVTT: -0.01908166
# [11:27:44] < Debug >     B_DIST: -0.4234399
# [11:27:44] < Debug >     B_TPTT:  0.0105587
# [11:27:44] < General >   Log likelihood (N=14260):  -8448.825 Gradient norm:      1e+04
# [11:27:44] < Debug >     ASC_AC:   2.661927
# [11:27:44] < Debug >     ASC_TR: -0.07984849
# [11:27:44] < Debug >     B_AIVTT: -0.02188668
# [11:27:44] < Debug >     B_DIST: -0.4323247
# [11:27:44] < Debug >     B_TPTT: 0.008556041
# [11:27:44] < General >   Log likelihood (N=14260):  -8429.541 Gradient norm:      2e+04
# [11:27:44] < Debug >     ASC_AC:   2.797237
# [11:27:44] < Debug >     ASC_TR: 0.05742689
# [11:27:44] < Debug >     B_AIVTT: -0.02594239
# [11:27:44] < Debug >     B_DIST: -0.4486338
# [11:27:44] < Debug >     B_TPTT: 0.005094203
# [11:27:44] < General >   Log likelihood (N=14260):  -8379.332 Gradient norm:      3e+04
# [11:27:44] < Debug >     ASC_AC:   3.059562
# [11:27:44] < Debug >     ASC_TR:  0.3649156
# [11:27:44] < Debug >     B_AIVTT: -0.02961601
# [11:27:44] < Debug >     B_DIST: -0.4723972
# [11:27:44] < Debug >     B_TPTT: 0.0002320667
# [11:27:44] < General >   Log likelihood (N=14260):  -8268.466 Gradient norm:      5e+04
# [11:27:44] < Debug >     ASC_AC:   3.520287
# [11:27:44] < Debug >     ASC_TR:  0.9641753
# [11:27:44] < Debug >     B_AIVTT: -0.02856754
# [11:27:44] < Debug >     B_DIST: -0.4979321
# [11:27:44] < Debug >     B_TPTT: -0.004870625
# [11:27:44] < General >   Log likelihood (N=14260):  -8054.755 Gradient norm:      6e+04
# [11:27:44] < Debug >     ASC_AC:   3.915817
# [11:27:44] < Debug >     ASC_TR:   1.711135
# [11:27:44] < Debug >     B_AIVTT: -0.01751263
# [11:27:44] < Debug >     B_DIST: -0.4872335
# [11:27:44] < Debug >     B_TPTT: -0.006341947
# [11:27:44] < General >   Log likelihood (N=14260):  -7802.248 Gradient norm:      4e+04
# [11:27:44] < Debug >     ASC_AC:   4.585102
# [11:27:44] < Debug >     ASC_TR:   2.064552
# [11:27:44] < Debug >     B_AIVTT: -0.01257647
# [11:27:44] < Debug >     B_DIST: -0.5521578
# [11:27:44] < Debug >     B_TPTT: -0.003289258
# [11:27:44] < General >   Log likelihood (N=14260):    -7819.4 Gradient norm:      3e+04
# [11:27:44] < Debug >     ASC_AC:   4.208933
# [11:27:44] < Debug >     ASC_TR:   1.865916
# [11:27:44] < Debug >     B_AIVTT: -0.01535082
# [11:27:44] < Debug >     B_DIST: -0.5156673
# [11:27:44] < Debug >     B_TPTT: -0.005005009
# [11:27:44] < General >   Log likelihood (N=14260):   -7764.79 Gradient norm:      9e+03
# [11:27:44] < Debug >     ASC_AC:   4.159832
# [11:27:44] < Debug >     ASC_TR:   2.073274
# [11:27:44] < Debug >     B_AIVTT: -0.008797933
# [11:27:44] < Debug >     B_DIST: -0.4845669
# [11:27:44] < Debug >     B_TPTT: -0.004491874
# [11:27:44] < General >   Log likelihood (N=14260):  -7727.799 Gradient norm:      8e+03
# [11:27:44] < Debug >     ASC_AC:   3.888985
# [11:27:44] < Debug >     ASC_TR:   2.194526
# [11:27:44] < Debug >     B_AIVTT: -0.01892216
# [11:27:44] < Debug >     B_DIST: -0.4424728
# [11:27:44] < Debug >     B_TPTT: -0.007954147
# [11:27:44] < General >   Log likelihood (N=14260):  -7755.491 Gradient norm:      6e+03
# [11:27:44] < Debug >     ASC_AC:   4.101156
# [11:27:44] < Debug >     ASC_TR:   2.099542
# [11:27:44] < Debug >     B_AIVTT: -0.01099125
# [11:27:44] < Debug >     B_DIST: -0.4754476
# [11:27:44] < Debug >     B_TPTT: -0.005241943
# [11:27:44] < General >   Log likelihood (N=14260):  -7725.505 Gradient norm:      5e+03
# [11:27:44] < Debug >     ASC_AC:   4.028169
# [11:27:44] < Debug >     ASC_TR:   2.080073
# [11:27:44] < Debug >     B_AIVTT: -0.008610125
# [11:27:44] < Debug >     B_DIST: -0.4629998
# [11:27:44] < Debug >     B_TPTT: -0.004218401
# [11:27:44] < General >   Log likelihood (N=14260):  -7722.095 Gradient norm:      2e+03
# [11:27:44] < Debug >     ASC_AC:   3.994423
# [11:27:44] < Debug >     ASC_TR:   2.045452
# [11:27:44] < Debug >     B_AIVTT: -0.00854804
# [11:27:44] < Debug >     B_DIST: -0.4609639
# [11:27:44] < Debug >     B_TPTT: -0.003880134
# [11:27:44] < General >   Log likelihood (N=14260):  -7721.626 Gradient norm:      6e+02
# [11:27:44] < Debug >     ASC_AC:   3.978051
# [11:27:44] < Debug >     ASC_TR:   2.027483
# [11:27:44] < Debug >     B_AIVTT: -0.008672457
# [11:27:44] < Debug >     B_DIST: -0.4605917
# [11:27:44] < Debug >     B_TPTT: -0.003766474
# [11:27:44] < General >   Log likelihood (N=14260):  -7721.471 Gradient norm:      4e+02
# [11:27:44] < Debug >     ASC_AC:   3.964009
# [11:27:44] < Debug >     ASC_TR:   2.011824
# [11:27:44] < Debug >     B_AIVTT: -0.008889091
# [11:27:44] < Debug >     B_DIST: -0.4611401
# [11:27:44] < Debug >     B_TPTT: -0.003711817
# [11:27:44] < General >   Log likelihood (N=14260):  -7721.236 Gradient norm:      7e+02
# [11:27:44] < Debug >     ASC_AC:    3.94561
# [11:27:44] < Debug >     ASC_TR:   1.991397
# [11:27:44] < Debug >     B_AIVTT: -0.009435322
# [11:27:44] < Debug >     B_DIST:  -0.464205
# [11:27:44] < Debug >     B_TPTT: -0.003749605
# [11:27:44] < General >   Log likelihood (N=14260):  -7720.676 Gradient norm:      1e+03
# [11:27:44] < Debug >     ASC_AC:   3.945002
# [11:27:44] < Debug >     ASC_TR:   1.993555
# [11:27:44] < Debug >     B_AIVTT: -0.009830811
# [11:27:44] < Debug >     B_DIST:  -0.468924
# [11:27:44] < Debug >     B_TPTT: -0.003939729
# [11:27:44] < General >   Log likelihood (N=14260):   -7720.13 Gradient norm:      1e+03
# [11:27:44] < Debug >     ASC_AC:   3.982163
# [11:27:44] < Debug >     ASC_TR:   2.002777
# [11:27:44] < Debug >     B_AIVTT: -0.01205756
# [11:27:44] < Debug >     B_DIST: -0.4796667
# [11:27:44] < Debug >     B_TPTT: -0.004871854
# [11:27:44] < General >   Log likelihood (N=14260):  -7720.946 Gradient norm:      2e+03
# [11:27:44] < Debug >     ASC_AC:   3.952834
# [11:27:44] < Debug >     ASC_TR:   1.995499
# [11:27:44] < Debug >     B_AIVTT: -0.01030013
# [11:27:44] < Debug >     B_DIST: -0.4711882
# [11:27:44] < Debug >     B_TPTT: -0.004136188
# [11:27:44] < General >   Log likelihood (N=14260):  -7720.067 Gradient norm:      6e+02
# [11:27:44] < Debug >     ASC_AC:   3.965238
# [11:27:44] < Debug >     ASC_TR:   2.014508
# [11:27:44] < Debug >     B_AIVTT: -0.01013857
# [11:27:44] < Debug >     B_DIST: -0.4732848
# [11:27:44] < Debug >     B_TPTT: -0.004259646
# [11:27:44] < General >   Log likelihood (N=14260):  -7719.891 Gradient norm:      2e+02
# [11:27:44] < Debug >     ASC_AC:    3.97816
# [11:27:44] < Debug >     ASC_TR:   2.025698
# [11:27:44] < Debug >     B_AIVTT: -0.01001547
# [11:27:44] < Debug >     B_DIST:  -0.474083
# [11:27:44] < Debug >     B_TPTT: -0.00427922
# [11:27:44] < General >   Log likelihood (N=14260):  -7719.887 Gradient norm:      6e+02
# [11:27:44] < Debug >     ASC_AC:   3.974935
# [11:27:44] < Debug >     ASC_TR:   2.031059
# [11:27:44] < Debug >     B_AIVTT: -0.009876447
# [11:27:44] < Debug >     B_DIST: -0.4728306
# [11:27:44] < Debug >     B_TPTT: -0.00435019
# [11:27:44] < General >   Log likelihood (N=14260):  -7719.903 Gradient norm:      8e+02
# [11:27:44] < Debug >     ASC_AC:   3.976921
# [11:27:44] < Debug >     ASC_TR:   2.027758
# [11:27:44] < Debug >     B_AIVTT: -0.009962055
# [11:27:44] < Debug >     B_DIST: -0.4736018
# [11:27:44] < Debug >     B_TPTT: -0.004306489
# [11:27:44] < General >   Log likelihood (N=14260):  -7719.876 Gradient norm:      5e+01
# [11:27:44] < Debug >     ASC_AC:   3.973558
# [11:27:44] < Debug >     ASC_TR:   2.024528
# [11:27:44] < Debug >     B_AIVTT: -0.009999393
# [11:27:44] < Debug >     B_DIST: -0.4733088
# [11:27:44] < Debug >     B_TPTT: -0.004296802
# [11:27:44] < General >   Log likelihood (N=14260):  -7719.874 Gradient norm:          3
# [11:27:44] < Debug >     ASC_AC:   3.973832
# [11:27:44] < Debug >     ASC_TR:   2.024412
# [11:27:44] < Debug >     B_AIVTT: -0.009990585
# [11:27:44] < Debug >     B_DIST: -0.4733401
# [11:27:44] < Debug >     B_TPTT: -0.004293642
# [11:27:44] < General >   Log likelihood (N=14260):  -7719.874 Gradient norm:      1e+01
# [11:27:44] < Debug >     ASC_AC:   3.973626
# [11:27:44] < Debug >     ASC_TR:   2.024499
# [11:27:44] < Debug >     B_AIVTT: -0.009997224
# [11:27:44] < Debug >     B_DIST: -0.4733165
# [11:27:44] < Debug >     B_TPTT: -0.004296024
# [11:27:44] < General >   Log likelihood (N=14260):  -7719.874 Gradient norm:        0.4
# [11:27:44] < Debug >     ASC_AC:   3.973643
# [11:27:44] < Debug >     ASC_TR:   2.024517
# [11:27:44] < Debug >     B_AIVTT: -0.009997041
# [11:27:44] < Debug >     B_DIST: -0.4733138
# [11:27:44] < Debug >     B_TPTT: -0.004296044
# [11:27:44] < General >   Log likelihood (N=14260):  -7719.874 Gradient norm:       0.06
# [11:27:44] < Debug >     ASC_AC:   3.973646
# [11:27:44] < Debug >     ASC_TR:    2.02452
# [11:27:44] < Debug >     B_AIVTT: -0.009997004
# [11:27:44] < Debug >     B_DIST: -0.4733131
# [11:27:44] < Debug >     B_TPTT: -0.004296043
# [11:27:44] < General >   Log likelihood (N=14260):  -7719.874 Gradient norm:      3e-05
# [11:27:44] < Debug >     ASC_AC:   3.973646
# [11:27:44] < Debug >     ASC_TR:    2.02452
# [11:27:44] < Debug >     B_AIVTT: -0.009997004
# [11:27:44] < Debug >     B_DIST: -0.4733131
# [11:27:44] < Debug >     B_TPTT: -0.004296043
# [11:27:44] < General >   Log likelihood (N=14260):  -7719.874 Gradient norm:      3e-05 Hessian norm:       2e+07 BHHH norm:       2e+07
# [11:27:44] < General >   Results saved in file SMTO_Logit_ModeChoice_ReRun2~00.html
# [11:27:44] < General >   Results saved in file SMTO_Logit_ModeChoice_ReRun2~00.pickle
# [11:27:44] < General >   Log file created: SMTO_Logit_ModeChoice_ReRun2~00.log
# ASC_AC    =	3.97
# ASC_TR    =	2.02
# B_AIVTT   =	-0.01
# B_DIST    =	-0.473
# B_TPTT    =	-0.0043
#             Value   Std err     t-test       p-value  Rob. Std err  \
# ASC_AC   3.973646  0.068612  57.914796  0.000000e+00      0.099714
# ASC_TR   2.024520  0.059370  34.099992  0.000000e+00      0.060326
# B_AIVTT -0.009997  0.001786  -5.597052  2.180268e-08      0.001892
# B_DIST  -0.473313  0.010485 -45.142485  0.000000e+00      0.023047
# B_TPTT  -0.004296  0.000694  -6.192388  5.925960e-10      0.000737
#
#          Rob. t-test  Rob. p-value
# ASC_AC     39.850339  0.000000e+00
# ASC_TR     33.559854  0.000000e+00
# B_AIVTT    -5.282694  1.272980e-07
# B_DIST    -20.537157  0.000000e+00
# B_TPTT     -5.829964  5.543945e-09

# %% [markdown]
# Upon running, this produces several output files. The most important is the html file.
#
# ### Resources
# UT Austin example: https://www.youtube.com/watch?v=QeJgyBIaXMQ
# Biogeme example: https://www.youtube.com/watch?v=OiM94B8WayA
# Nested logit example: https://www.youtube.com/watch?v=vEhvf54IKvs
