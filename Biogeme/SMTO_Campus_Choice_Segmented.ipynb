# %% [markdown]
# # Biogeme Test - SMTO Data
#
# Gonna try to adapt the Biogeme Swissmetro example to university choice using SMTO data set. We'll try to predict campus choice using distance.

# %%
import biogeme.database as db
import biogeme.biogeme as bio
import biogeme.models as models
from biogeme.expressions import Beta, DefineVariable
import biogeme.messaging as msg
import pandas as pd

hh_df = pd.read_csv('../Data/SMTO_2015/SMTO_2015_Households.csv')
ps_df = pd.read_csv('../Data/SMTO_2015/SMTO_2015_Respondents.csv')

# %%
# Load relevant columns
df = ps_df[['pscampusattend']]
df = df.join(hh_df[['HmTTS2006', 'hhlivingsituation']])
df = df.rename(columns={'HmTTS2006': 'HomeZone', 'pscampusattend': 'Campus', 'hhlivingsituation': 'Family'})
df = df.dropna() # Remove rows with missing data

# Convert Campus column to numerical column
campus_name_to_num = {"Downtown Toronto (St. George)": 0, "Scarborough (UTSC)": 1, "Mississauga (UTM)": 2,
                      "Keele": 3, "Glendon": 4, "RyersonU": 5, "OCADu": 6}
df.replace({'Campus': campus_name_to_num}, inplace=True)
df['HomeZone'] = pd.to_numeric(df['HomeZone'], downcast='signed')
df['Family'] = (df['Family'] == 'Live with family/parents')*1

df
# Out:
#        Campus  HomeZone  Family
# 0           1       261       1
# 1           0        71       0
# 2           0      3714       1
# 3           0        74       0
# 4           0        71       0
# ...       ...       ...     ...
# 15221       3       212       0
# 15222       3       233       1
# 15223       3        95       0
# 15224       3      2221       1
# 15225       3      3686       1
#
# [14988 rows x 3 columns]

# %%
# Dataframe with walk distances
df_path = pd.read_csv('../../LoS/Walk_Distances.csv')
origins = list(set(list(df_path['Origin'])))
dists = list(df_path['Data'])

# %%
not_found = set()
# Function for distance lookup
def find_distance(origin, destination):
    try:
        i = origins.index(origin)
    except ValueError:
        not_found.add(origin)
        return 0
    try:
        j = origins.index(destination)
    except ValueError:
        not_found.add(destination)
        return 0
    return dists[i*2392 + j] / 1000

# %%
# List of campus' TTS zones from Joven's MOE data
campus_zones = [69, 566, 3631, 391, 225, 38, 67]

# Load distances in dataframe
for i in range(7):
    df["Dist" + str(i)] = df['HomeZone'].apply(lambda x: find_distance(x, campus_zones[i]))
len(not_found)
# Out:
# 128

# %%
df
# Out:
#        Campus  HomeZone  Family      Dist0     Dist1     Dist2     Dist3  \
# 0           1       261       1  10.256060  14.88098  29.20657  22.59214
# 1           0        71       0   1.132351  23.03920  19.64290  15.87906
# 2           0      3714       1  23.319230  45.63271   4.51742  28.58045
# 3           0        74       0   0.699414  24.11954  19.43932  16.81186
# 4           0        71       0   1.132351  23.03920  19.64290  15.87906
# ...       ...       ...     ...        ...       ...       ...       ...
# 15221       3       212       0   7.120260  19.01731  23.76046  14.19530
# 15222       3       233       1  15.917590  12.03644  32.96591  17.68772
# 15223       3        95       0   2.783940  25.09743  17.84462  15.53600
# 15224       3      2221       1  23.379880  26.15476  37.35434  13.30458
# 15225       3      3686       1  35.537980  53.96100  16.14689  34.80651
#
#            Dist4      Dist5      Dist6
# 0       9.218413   9.580635  11.241730
# 1      11.211150   2.675173   2.723838
# 2      32.555200  24.964000  23.686150
# 3      12.830410   2.314008   1.541276
# 4      11.211150   2.675173   2.723838
# ...          ...        ...        ...
# 15221   5.732956   6.553092   8.193741
# 15222   6.019180  15.242170  16.903260
# 15223  12.829600   4.733398   3.979057
# 15224  15.379040  23.250580  24.518920
# 15225  40.034760  36.584780  34.882980
#
# [14988 rows x 10 columns]

# %%
# Load data into Biogeme database
database = db.Database("SMTO", df)

# Definition of new variables: adding columns to the database 
Available =  DefineVariable('Available', 1, database) # All schools available to all students

# Make variable names global
globals().update(database.variables)

# Remove unknown zones
database.remove(Dist0 == 0)
database.data
# Out:
#        Campus  HomeZone  Family      Dist0     Dist1     Dist2     Dist3  \
# 0           1       261       1  10.256060  14.88098  29.20657  22.59214
# 1           0        71       0   1.132351  23.03920  19.64290  15.87906
# 2           0      3714       1  23.319230  45.63271   4.51742  28.58045
# 3           0        74       0   0.699414  24.11954  19.43932  16.81186
# 4           0        71       0   1.132351  23.03920  19.64290  15.87906
# ...       ...       ...     ...        ...       ...       ...       ...
# 15221       3       212       0   7.120260  19.01731  23.76046  14.19530
# 15222       3       233       1  15.917590  12.03644  32.96591  17.68772
# 15223       3        95       0   2.783940  25.09743  17.84462  15.53600
# 15224       3      2221       1  23.379880  26.15476  37.35434  13.30458
# 15225       3      3686       1  35.537980  53.96100  16.14689  34.80651
#
#            Dist4      Dist5      Dist6  Available
# 0       9.218413   9.580635  11.241730          1
# 1      11.211150   2.675173   2.723838          1
# 2      32.555200  24.964000  23.686150          1
# 3      12.830410   2.314008   1.541276          1
# 4      11.211150   2.675173   2.723838          1
# ...          ...        ...        ...        ...
# 15221   5.732956   6.553092   8.193741          1
# 15222   6.019180  15.242170  16.903260          1
# 15223  12.829600   4.733398   3.979057          1
# 15224  15.379040  23.250580  24.518920          1
# 15225  40.034760  36.584780  34.882980          1
#
# [14667 rows x 11 columns]

# %%
"""
# Here we use the "biogeme" way for backward compatibility
exclude = HomeToMainCampusKM > 130
database.remove(exclude)
database.data

# Parameters to be estimated
ASC_CAR = Beta('ASC_CAR',0,None,None,0)
ASC_TRAIN = Beta('ASC_TRAIN',0,None,None,0)
ASC_SM = Beta('ASC_SM',0,None,None,1)
B_TIME = Beta('B_TIME',0,None,None,0)
B_COST = Beta('B_COST',0,None,None,0)

# Definition of new variables
SM_COST =  SM_CO   * (  GA   ==  0  ) 
TRAIN_COST =  TRAIN_CO   * (  GA   ==  0  )

# Definition of new variables: adding columns to the database 
CAR_AV_SP =  DefineVariable('CAR_AV_SP',CAR_AV  * (  SP   !=  0  ),database)
TRAIN_AV_SP =  DefineVariable('TRAIN_AV_SP',TRAIN_AV  * (  SP   !=  0  ),database)
TRAIN_TT_SCALED = DefineVariable('TRAIN_TT_SCALED',\
                                 TRAIN_TT / 100.0,database)
TRAIN_COST_SCALED = DefineVariable('TRAIN_COST_SCALED',\
                                   TRAIN_COST / 100,database)
SM_TT_SCALED = DefineVariable('SM_TT_SCALED', SM_TT / 100.0,database)
SM_COST_SCALED = DefineVariable('SM_COST_SCALED', SM_COST / 100,database)
CAR_TT_SCALED = DefineVariable('CAR_TT_SCALED', CAR_TT / 100,database)
CAR_CO_SCALED = DefineVariable('CAR_CO_SCALED', CAR_CO / 100,database)

# Definition of the utility functions
V1 = ASC_TRAIN + \
     B_TIME * TRAIN_TT_SCALED + \
     B_COST * TRAIN_COST_SCALED
V2 = ASC_SM + \
     B_TIME * SM_TT_SCALED + \
     B_COST * SM_COST_SCALED
V3 = ASC_CAR + \
     B_TIME * CAR_TT_SCALED + \
     B_COST * CAR_CO_SCALED

# Associate utility functions with the numbering of alternatives
V = {1: V1,
     2: V2,
     3: V3}

# Associate the availability conditions with the alternatives
av = {1: TRAIN_AV_SP,
      2: SM_AV,
      3: CAR_AV_SP}
      
# Definition of the model. This is the contribution of each
# observation to the log likelihood function.
logprob = models.loglogit(V,av,CHOICE)

"""
# Beta initialization: (name, value, lowerbound, upperbound, status, desc='')
# Status 0 if estimated, 1 if maintained - reference choice should be 1
ASC_SG = Beta('ASC_SG', 0, None, None, 0)
ASC_SC = Beta('ASC_SC', 0, None, None, 0)
ASC_MI = Beta('ASC_MI', 0, None, None, 0)
ASC_YK = Beta('ASC_YK', 0, None, None, 0)
ASC_YG = Beta('ASC_YG', 0, None, None, 1)
ASC_RY = Beta('ASC_RY', 0, None, None, 0)
ASC_OC = Beta('ASC_OC', 0, None, None, 0)
B_DIST = Beta('B_DIST', 0, None, None, 0)

# Variables: from columns in database
AV = DefineVariable('AV', Available, database)
SG_DIST = DefineVariable('SG_DIST', Dist0, database)
SC_DIST = DefineVariable('SC_DIST', Dist1, database)
MI_DIST = DefineVariable('MI_DIST', Dist2, database)
YK_DIST = DefineVariable('YK_DIST', Dist3, database)
YG_DIST = DefineVariable('YG_DIST', Dist4, database)
RY_DIST = DefineVariable('RY_DIST', Dist5, database)
OC_DIST = DefineVariable('OC_DIST', Dist6, database)

# Utility Functions: note ASC_SG is 0
V0 = ASC_SG + B_DIST * SG_DIST
V1 = ASC_SC + B_DIST * SC_DIST
V2 = ASC_MI + B_DIST * MI_DIST
V3 = ASC_YK + B_DIST * YK_DIST
V4 = ASC_YG + B_DIST * YG_DIST
V5 = ASC_RY + B_DIST * RY_DIST
V6 = ASC_OC + B_DIST * OC_DIST

V  = {0: V0, 1: V1, 2: V2, 3: V3, 4: V4, 5: V5, 6: V6}
av = {0: AV, 1: AV, 2: AV, 3: AV, 4: AV, 5: AV, 6: AV}

# %%
database.data
# Out:
#        Campus  HomeZone  Family      Dist0     Dist1     Dist2     Dist3  \
# 0           1       261       1  10.256060  14.88098  29.20657  22.59214
# 1           0        71       0   1.132351  23.03920  19.64290  15.87906
# 2           0      3714       1  23.319230  45.63271   4.51742  28.58045
# 3           0        74       0   0.699414  24.11954  19.43932  16.81186
# 4           0        71       0   1.132351  23.03920  19.64290  15.87906
# ...       ...       ...     ...        ...       ...       ...       ...
# 15221       3       212       0   7.120260  19.01731  23.76046  14.19530
# 15222       3       233       1  15.917590  12.03644  32.96591  17.68772
# 15223       3        95       0   2.783940  25.09743  17.84462  15.53600
# 15224       3      2221       1  23.379880  26.15476  37.35434  13.30458
# 15225       3      3686       1  35.537980  53.96100  16.14689  34.80651
#
#            Dist4      Dist5      Dist6  Available   AV    SG_DIST   SC_DIST  \
# 0       9.218413   9.580635  11.241730          1  1.0  10.256060  14.88098
# 1      11.211150   2.675173   2.723838          1  1.0   1.132351  23.03920
# 2      32.555200  24.964000  23.686150          1  1.0  23.319230  45.63271
# 3      12.830410   2.314008   1.541276          1  1.0   0.699414  24.11954
# 4      11.211150   2.675173   2.723838          1  1.0   1.132351  23.03920
# ...          ...        ...        ...        ...  ...        ...       ...
# 15221   5.732956   6.553092   8.193741          1  1.0   7.120260  19.01731
# 15222   6.019180  15.242170  16.903260          1  1.0  15.917590  12.03644
# 15223  12.829600   4.733398   3.979057          1  1.0   2.783940  25.09743
# 15224  15.379040  23.250580  24.518920          1  1.0  23.379880  26.15476
# 15225  40.034760  36.584780  34.882980          1  1.0  35.537980  53.96100
#
#         MI_DIST   YK_DIST    YG_DIST    RY_DIST    OC_DIST
# 0      29.20657  22.59214   9.218413   9.580635  11.241730
# 1      19.64290  15.87906  11.211150   2.675173   2.723838
# 2       4.51742  28.58045  32.555200  24.964000  23.686150
# 3      19.43932  16.81186  12.830410   2.314008   1.541276
# 4      19.64290  15.87906  11.211150   2.675173   2.723838
# ...         ...       ...        ...        ...        ...
# 15221  23.76046  14.19530   5.732956   6.553092   8.193741
# 15222  32.96591  17.68772   6.019180  15.242170  16.903260
# 15223  17.84462  15.53600  12.829600   4.733398   3.979057
# 15224  37.35434  13.30458  15.379040  23.250580  24.518920
# 15225  16.14689  34.80651  40.034760  36.584780  34.882980
#
# [14667 rows x 19 columns]

# %%
def run_biogeme(run_name, val_to_keep):
    logprob = models.loglogit(V, av, Campus)
    logger = msg.bioMessage()
    logger.setDebug()
    database.remove(Family != val_to_keep)
    biogeme = bio.BIOGEME(database, logprob, numberOfThreads=1)
    biogeme.modelName = run_name
    results = biogeme.estimate(saveIterations=True)
    biogeme.createLogFile()
    betas = results.getBetaValues()
    for k,v in betas.items():
        print(f"{k:10}=\t{v:.3g}")
    pandasResults = results.getEstimatedParameters()
    print(pandasResults)

# %%
#run_biogeme("SMTO_Family", 1)
run_biogeme("SMTO_Other", 0)
# Out:
# [10:18:39] < General >   Remove 10 unused variables from the database as only 9 are used.
# [10:18:40] < General >   Log likelihood (N=6329):  -12315.67
# [10:18:40] < General >   Minimize with tol 1e-07
# [10:18:40] < Debug >     ASC_MI:          0
# [10:18:40] < Debug >     ASC_OC:          0
# [10:18:40] < Debug >     ASC_RY:          0
# [10:18:40] < Debug >     ASC_SC:          0
# [10:18:40] < Debug >     ASC_SG:          0
# [10:18:40] < Debug >     ASC_YK:          0
# [10:18:40] < Debug >     B_DIST:          0
# [10:18:40] < General >   Log likelihood (N=6329):  -12315.67 Gradient norm:      5e+04
# [10:18:40] < Debug >     ASC_MI: -0.01283565
# [10:18:40] < Debug >     ASC_OC: -0.01370328
# [10:18:40] < Debug >     ASC_RY: 0.0009858059
# [10:18:40] < Debug >     ASC_SC: -0.01245229
# [10:18:40] < Debug >     ASC_SG: 0.05019828
# [10:18:40] < Debug >     ASC_YK: 0.003649211
# [10:18:40] < Debug >     B_DIST:  -0.998478
# [10:18:40] < General >   Log likelihood (N=6329):  -21346.55 Gradient norm:      2e+04
# [10:18:40] < Debug >     ASC_MI: -0.003621128
# [10:18:40] < Debug >     ASC_OC: -0.003865898
# [10:18:40] < Debug >     ASC_RY: 0.0002781105
# [10:18:40] < Debug >     ASC_SC: -0.003512974
# [10:18:40] < Debug >     ASC_SG: 0.01416168
# [10:18:40] < Debug >     ASC_YK: 0.001029497
# [10:18:40] < Debug >     B_DIST: -0.2816854
# [10:18:40] < General >   Log likelihood (N=6329):  -10147.37 Gradient norm:      1e+04
# [10:18:40] < Debug >     ASC_MI: -0.004170432
# [10:18:40] < Debug >     ASC_OC: -0.008128739
# [10:18:40] < Debug >     ASC_RY: -0.001487348
# [10:18:40] < Debug >     ASC_SC: -0.003604278
# [10:18:40] < Debug >     ASC_SG: 0.02035088
# [10:18:40] < Debug >     ASC_YK: 0.002603769
# [10:18:40] < Debug >     B_DIST: -0.2275987
# [10:18:40] < General >   Log likelihood (N=6329):   -9554.34 Gradient norm:      9e+03
# [10:18:40] < Debug >     ASC_MI: -0.00981318
# [10:18:40] < Debug >     ASC_OC: -0.04466567
# [10:18:40] < Debug >     ASC_RY: -0.01589181
# [10:18:40] < Debug >     ASC_SC: -0.005088721
# [10:18:40] < Debug >     ASC_SG: 0.07848976
# [10:18:40] < Debug >     ASC_YK: 0.01675246
# [10:18:40] < Debug >     B_DIST: -0.04539968
# [10:18:40] < General >   Log likelihood (N=6329):  -10298.94 Gradient norm:      3e+04
# [10:18:40] < Debug >     ASC_MI: -0.00647485
# [10:18:40] < Debug >     ASC_OC: -0.0230499
# [10:18:40] < Debug >     ASC_RY: -0.007369926
# [10:18:40] < Debug >     ASC_SC: -0.004210504
# [10:18:40] < Debug >     ASC_SG: 0.04409397
# [10:18:40] < Debug >     ASC_YK: 0.008381894
# [10:18:40] < Debug >     B_DIST: -0.1531912
# [10:18:40] < General >   Log likelihood (N=6329):  -9074.673 Gradient norm:      2e+03
# [10:18:40] < Debug >     ASC_MI: -0.009047503
# [10:18:40] < Debug >     ASC_OC: -0.03764306
# [10:18:40] < Debug >     ASC_RY: -0.01283456
# [10:18:40] < Debug >     ASC_SC: -0.005102497
# [10:18:40] < Debug >     ASC_SG: 0.06850327
# [10:18:40] < Debug >     ASC_YK: 0.01406569
# [10:18:40] < Debug >     B_DIST: -0.1376989
# [10:18:40] < General >   Log likelihood (N=6329):  -9015.927 Gradient norm:      3e+03
# [10:18:40] < Debug >     ASC_MI: -0.01657912
# [10:18:40] < Debug >     ASC_OC: -0.07908476
# [10:18:40] < Debug >     ASC_RY: -0.0281612
# [10:18:40] < Debug >     ASC_SC: -0.007849256
# [10:18:40] < Debug >     ASC_SG:  0.1385494
# [10:18:40] < Debug >     ASC_YK: 0.03023323
# [10:18:40] < Debug >     B_DIST: -0.1256293
# [10:18:40] < General >   Log likelihood (N=6329):   -8868.56 Gradient norm:      5e+03
# [10:18:40] < Debug >     ASC_MI: -0.0628446
# [10:18:40] < Debug >     ASC_OC: -0.3310455
# [10:18:40] < Debug >     ASC_RY: -0.1209133
# [10:18:40] < Debug >     ASC_SC: -0.0249347
# [10:18:40] < Debug >     ASC_SG:  0.5656079
# [10:18:40] < Debug >     ASC_YK:  0.1288803
# [10:18:40] < Debug >     B_DIST: -0.09624005
# [10:18:40] < General >   Log likelihood (N=6329):  -8171.481 Gradient norm:      1e+04
# [10:18:40] < Debug >     ASC_MI:  -0.119604
# [10:18:40] < Debug >     ASC_OC: -0.6365713
# [10:18:40] < Debug >     ASC_RY: -0.2315864
# [10:18:40] < Debug >     ASC_SC: -0.04612925
# [10:18:40] < Debug >     ASC_SG:     1.0832
# [10:18:40] < Debug >     ASC_YK:  0.2501011
# [10:18:40] < Debug >     B_DIST: -0.09949265
# [10:18:40] < General >   Log likelihood (N=6329):  -7532.275 Gradient norm:      9e+03
# [10:18:40] < Debug >     ASC_MI: -0.1522286
# [10:18:40] < Debug >     ASC_OC: -0.8114068
# [10:18:40] < Debug >     ASC_RY:  -0.269102
# [10:18:40] < Debug >     ASC_SC: -0.05599619
# [10:18:40] < Debug >     ASC_SG:   1.340396
# [10:18:40] < Debug >     ASC_YK:  0.3465731
# [10:18:40] < Debug >     B_DIST:  -0.122345
# [10:18:40] < General >   Log likelihood (N=6329):  -7295.798 Gradient norm:      3e+03
# [10:18:40] < Debug >     ASC_MI: -0.1596606
# [10:18:40] < Debug >     ASC_OC: -0.8495912
# [10:18:40] < Debug >     ASC_RY: -0.2674488
# [10:18:40] < Debug >     ASC_SC: -0.05744927
# [10:18:40] < Debug >     ASC_SG:   1.382282
# [10:18:40] < Debug >     ASC_YK:   0.378098
# [10:18:40] < Debug >     B_DIST: -0.1363308
# [10:18:40] < General >   Log likelihood (N=6329):  -7258.609 Gradient norm:      7e+02
# [10:18:40] < Debug >     ASC_MI: -0.1614789
# [10:18:40] < Debug >     ASC_OC: -0.8569446
# [10:18:40] < Debug >     ASC_RY: -0.2597518
# [10:18:40] < Debug >     ASC_SC: -0.05729997
# [10:18:40] < Debug >     ASC_SG:   1.379999
# [10:18:40] < Debug >     ASC_YK:  0.3920592
# [10:18:40] < Debug >     B_DIST: -0.1430096
# [10:18:40] < General >   Log likelihood (N=6329):  -7250.108 Gradient norm:      9e+02
# [10:18:40] < Debug >     ASC_MI: -0.1632999
# [10:18:40] < Debug >     ASC_OC: -0.8626799
# [10:18:40] < Debug >     ASC_RY: -0.2496252
# [10:18:40] < Debug >     ASC_SC: -0.05705181
# [10:18:40] < Debug >     ASC_SG:    1.37286
# [10:18:40] < Debug >     ASC_YK:  0.4074478
# [10:18:40] < Debug >     B_DIST: -0.1472451
# [10:18:40] < General >   Log likelihood (N=6329):  -7243.019 Gradient norm:      2e+03
# [10:18:40] < Debug >     ASC_MI: -0.1699479
# [10:18:40] < Debug >     ASC_OC: -0.8841964
# [10:18:40] < Debug >     ASC_RY: -0.2200287
# [10:18:40] < Debug >     ASC_SC: -0.05675394
# [10:18:40] < Debug >     ASC_SG:   1.358456
# [10:18:40] < Debug >     ASC_YK:  0.4563449
# [10:18:40] < Debug >     B_DIST: -0.1546237
# [10:18:40] < General >   Log likelihood (N=6329):  -7223.472 Gradient norm:      3e+03
# [10:18:40] < Debug >     ASC_MI: -0.1875739
# [10:18:40] < Debug >     ASC_OC: -0.9433832
# [10:18:40] < Debug >     ASC_RY: -0.1551372
# [10:18:40] < Debug >     ASC_SC: -0.05699609
# [10:18:40] < Debug >     ASC_SG:   1.342565
# [10:18:40] < Debug >     ASC_YK:   0.573365
# [10:18:40] < Debug >     B_DIST: -0.1639815
# [10:18:40] < General >   Log likelihood (N=6329):  -7181.918 Gradient norm:      4e+03
# [10:18:40] < Debug >     ASC_MI: -0.2282545
# [10:18:40] < Debug >     ASC_OC:  -1.082905
# [10:18:40] < Debug >     ASC_RY: -0.0253547
# [10:18:40] < Debug >     ASC_SC: -0.0590275
# [10:18:40] < Debug >     ASC_SG:   1.338753
# [10:18:40] < Debug >     ASC_YK:   0.825023
# [10:18:40] < Debug >     B_DIST:  -0.173063
# [10:18:40] < General >   Log likelihood (N=6329):   -7102.73 Gradient norm:      5e+03
# [10:18:40] < Debug >     ASC_MI: -0.2960204
# [10:18:40] < Debug >     ASC_OC:  -1.322961
# [10:18:40] < Debug >     ASC_RY:  0.1430104
# [10:18:40] < Debug >     ASC_SC: -0.06535659
# [10:18:40] < Debug >     ASC_SG:   1.413257
# [10:18:40] < Debug >     ASC_YK:     1.2029
# [10:18:40] < Debug >     B_DIST: -0.1732369
# [10:18:40] < General >   Log likelihood (N=6329):  -7001.739 Gradient norm:      4e+03
# [10:18:40] < Debug >     ASC_MI: -0.3420202
# [10:18:40] < Debug >     ASC_OC:  -1.466047
# [10:18:40] < Debug >     ASC_RY:  0.2538311
# [10:18:40] < Debug >     ASC_SC: -0.06737727
# [10:18:40] < Debug >     ASC_SG:   1.481941
# [10:18:40] < Debug >     ASC_YK:   1.446278
# [10:18:40] < Debug >     B_DIST: -0.1600172
# [10:18:40] < General >   Log likelihood (N=6329):  -6944.115 Gradient norm:      2e+03
# [10:18:41] < Debug >     ASC_MI: -0.3459572
# [10:18:41] < Debug >     ASC_OC:  -1.479449
# [10:18:41] < Debug >     ASC_RY:  0.2407572
# [10:18:41] < Debug >     ASC_SC: -0.06779259
# [10:18:41] < Debug >     ASC_SG:   1.534825
# [10:18:41] < Debug >     ASC_YK:   1.445542
# [10:18:41] < Debug >     B_DIST: -0.1509337
# [10:18:41] < General >   Log likelihood (N=6329):  -6934.028 Gradient norm:      2e+02
# [10:18:41] < Debug >     ASC_MI: -0.3387529
# [10:18:41] < Debug >     ASC_OC:  -1.450528
# [10:18:41] < Debug >     ASC_RY:  0.2255854
# [10:18:41] < Debug >     ASC_SC: -0.06659593
# [10:18:41] < Debug >     ASC_SG:   1.524497
# [10:18:41] < Debug >     ASC_YK:    1.40581
# [10:18:41] < Debug >     B_DIST: -0.1487622
# [10:18:41] < General >   Log likelihood (N=6329):   -6932.78 Gradient norm:      1e+02
# [10:18:41] < Debug >     ASC_MI: -0.3340931
# [10:18:41] < Debug >     ASC_OC:  -1.429957
# [10:18:41] < Debug >     ASC_RY:  0.2207656
# [10:18:41] < Debug >     ASC_SC: -0.06504266
# [10:18:41] < Debug >     ASC_SG:   1.513363
# [10:18:41] < Debug >     ASC_YK:   1.383227
# [10:18:41] < Debug >     B_DIST: -0.1479154
# [10:18:41] < General >   Log likelihood (N=6329):  -6932.252 Gradient norm:      2e+02
# [10:18:41] < Debug >     ASC_MI:  -0.330629
# [10:18:41] < Debug >     ASC_OC:  -1.410174
# [10:18:41] < Debug >     ASC_RY:  0.2254388
# [10:18:41] < Debug >     ASC_SC: -0.06153836
# [10:18:41] < Debug >     ASC_SG:   1.506863
# [10:18:41] < Debug >     ASC_YK:   1.369592
# [10:18:41] < Debug >     B_DIST: -0.1472579
# [10:18:41] < General >   Log likelihood (N=6329):  -6931.156 Gradient norm:      2e+02
# [10:18:41] < Debug >     ASC_MI:  -0.320244
# [10:18:41] < Debug >     ASC_OC:  -1.332697
# [10:18:41] < Debug >     ASC_RY:  0.2684717
# [10:18:41] < Debug >     ASC_SC: -0.04123796
# [10:18:41] < Debug >     ASC_SG:   1.506227
# [10:18:41] < Debug >     ASC_YK:   1.337484
# [10:18:41] < Debug >     B_DIST: -0.1450211
# [10:18:41] < General >   Log likelihood (N=6329):  -6925.766 Gradient norm:      5e+02
# [10:18:41] < Debug >     ASC_MI: -0.3115175
# [10:18:41] < Debug >     ASC_OC:  -1.231386
# [10:18:41] < Debug >     ASC_RY:   0.360289
# [10:18:41] < Debug >     ASC_SC: -0.004235322
# [10:18:41] < Debug >     ASC_SG:   1.550044
# [10:18:41] < Debug >     ASC_YK:   1.327781
# [10:18:41] < Debug >     B_DIST: -0.1426746
# [10:18:41] < General >   Log likelihood (N=6329):  -6917.229 Gradient norm:      6e+02
# [10:18:41] < Debug >     ASC_MI: -0.3069811
# [10:18:41] < Debug >     ASC_OC:  -1.109396
# [10:18:41] < Debug >     ASC_RY:  0.5215736
# [10:18:41] < Debug >     ASC_SC:  0.0575388
# [10:18:41] < Debug >     ASC_SG:    1.67183
# [10:18:41] < Debug >     ASC_YK:   1.371054
# [10:18:41] < Debug >     B_DIST: -0.1411283
# [10:18:41] < General >   Log likelihood (N=6329):  -6905.068 Gradient norm:      7e+02
# [10:18:41] < Debug >     ASC_MI:  -0.237765
# [10:18:41] < Debug >     ASC_OC: -0.8622571
# [10:18:41] < Debug >     ASC_RY:  0.7191182
# [10:18:41] < Debug >     ASC_SC:  0.2025533
# [10:18:41] < Debug >     ASC_SG:   1.794449
# [10:18:41] < Debug >     ASC_YK:   1.518524
# [10:18:41] < Debug >     B_DIST: -0.1459524
# [10:18:41] < General >   Log likelihood (N=6329):  -6887.987 Gradient norm:      2e+02
# [10:18:41] < Debug >     ASC_MI: -0.1608229
# [10:18:41] < Debug >     ASC_OC: -0.6382861
# [10:18:41] < Debug >     ASC_RY:   0.917748
# [10:18:41] < Debug >     ASC_SC:  0.3737863
# [10:18:41] < Debug >     ASC_SG:   2.014893
# [10:18:41] < Debug >     ASC_YK:   1.768524
# [10:18:41] < Debug >     B_DIST: -0.1464869
# [10:18:41] < General >   Log likelihood (N=6329):  -6866.636 Gradient norm:      2e+02
# [10:18:41] < Debug >     ASC_MI:  0.1336264
# [10:18:41] < Debug >     ASC_OC: -0.1498249
# [10:18:41] < Debug >     ASC_RY:   1.047495
# [10:18:41] < Debug >     ASC_SC:  0.7051358
# [10:18:41] < Debug >     ASC_SG:   2.323534
# [10:18:41] < Debug >     ASC_YK:    1.98704
# [10:18:41] < Debug >     B_DIST: -0.1439534
# [10:18:41] < General >   Log likelihood (N=6329):  -6847.832 Gradient norm:      2e+02
# [10:18:41] < Debug >     ASC_MI:   2.548237
# [10:18:41] < Debug >     ASC_OC:   2.158718
# [10:18:41] < Debug >     ASC_RY:   3.352759
# [10:18:41] < Debug >     ASC_SC:   3.475896
# [10:18:41] < Debug >     ASC_SG:   4.081019
# [10:18:41] < Debug >     ASC_YK:   6.458289
# [10:18:41] < Debug >     B_DIST: -0.05516717
# [10:18:41] < General >   Log likelihood (N=6329):  -12885.21 Gradient norm:      5e+04
# [10:18:41] < Debug >     ASC_MI:  0.2002577
# [10:18:41] < Debug >     ASC_OC: -0.08612054
# [10:18:41] < Debug >     ASC_RY:   1.111108
# [10:18:41] < Debug >     ASC_SC:   0.781595
# [10:18:41] < Debug >     ASC_SG:   2.372032
# [10:18:41] < Debug >     ASC_YK:   2.110424
# [10:18:41] < Debug >     B_DIST: -0.1415033
# [10:18:41] < General >   Log likelihood (N=6329):  -6842.271 Gradient norm:      5e+02
# [10:18:41] < Debug >     ASC_MI:  0.2225257
# [10:18:41] < Debug >     ASC_OC: -0.1433859
# [10:18:41] < Debug >     ASC_RY:   1.094111
# [10:18:41] < Debug >     ASC_SC:  0.7867409
# [10:18:41] < Debug >     ASC_SG:   2.346114
# [10:18:41] < Debug >     ASC_YK:   2.182391
# [10:18:41] < Debug >     B_DIST: -0.1444946
# [10:18:41] < General >   Log likelihood (N=6329):  -6838.166 Gradient norm:      2e+02
# [10:18:41] < Debug >     ASC_MI:   0.249875
# [10:18:41] < Debug >     ASC_OC: -0.1580131
# [10:18:41] < Debug >     ASC_RY:    1.09352
# [10:18:41] < Debug >     ASC_SC:  0.7995727
# [10:18:41] < Debug >     ASC_SG:   2.354552
# [10:18:41] < Debug >     ASC_YK:   2.201393
# [10:18:41] < Debug >     B_DIST: -0.1456465
# [10:18:41] < General >   Log likelihood (N=6329):  -6836.443 Gradient norm:      9e+01
# [10:18:41] < Debug >     ASC_MI:  0.3984881
# [10:18:41] < Debug >     ASC_OC: -0.1967583
# [10:18:41] < Debug >     ASC_RY:   1.123751
# [10:18:41] < Debug >     ASC_SC:  0.8755076
# [10:18:41] < Debug >     ASC_SG:   2.407456
# [10:18:41] < Debug >     ASC_YK:   2.271358
# [10:18:41] < Debug >     B_DIST: -0.1468984
# [10:18:41] < General >   Log likelihood (N=6329):  -6830.252 Gradient norm:      2e+02
# [10:18:41] < Debug >     ASC_MI:  0.5913816
# [10:18:41] < Debug >     ASC_OC: -0.1927631
# [10:18:41] < Debug >     ASC_RY:   1.198908
# [10:18:41] < Debug >     ASC_SC:  0.9847876
# [10:18:41] < Debug >     ASC_SG:   2.482327
# [10:18:41] < Debug >     ASC_YK:   2.331744
# [10:18:41] < Debug >     B_DIST: -0.1459595
# [10:18:41] < General >   Log likelihood (N=6329):  -6824.549 Gradient norm:      3e+02
# [10:18:41] < Debug >     ASC_MI:  0.7896633
# [10:18:41] < Debug >     ASC_OC: -0.1212961
# [10:18:41] < Debug >     ASC_RY:    1.32827
# [10:18:41] < Debug >     ASC_SC:   1.118436
# [10:18:41] < Debug >     ASC_SG:   2.583189
# [10:18:41] < Debug >     ASC_YK:   2.384471
# [10:18:41] < Debug >     B_DIST:  -0.143271
# [10:18:41] < General >   Log likelihood (N=6329):  -6820.342 Gradient norm:      2e+02
# [10:18:41] < Debug >     ASC_MI:  0.8308038
# [10:18:41] < Debug >     ASC_OC: -0.07862757
# [10:18:41] < Debug >     ASC_RY:   1.373622
# [10:18:41] < Debug >     ASC_SC:   1.153788
# [10:18:41] < Debug >     ASC_SG:   2.602033
# [10:18:41] < Debug >     ASC_YK:   2.393868
# [10:18:41] < Debug >     B_DIST: -0.1412813
# [10:18:41] < General >   Log likelihood (N=6329):  -6819.739 Gradient norm:      8e+01
# [10:18:41] < Debug >     ASC_MI:  0.8252272
# [10:18:41] < Debug >     ASC_OC: -0.05348382
# [10:18:41] < Debug >     ASC_RY:   1.387715
# [10:18:41] < Debug >     ASC_SC:   1.159916
# [10:18:41] < Debug >     ASC_SG:   2.616967
# [10:18:41] < Debug >     ASC_YK:   2.393373
# [10:18:41] < Debug >     B_DIST: -0.1416127
# [10:18:41] < General >   Log likelihood (N=6329):  -6819.597 Gradient norm:      1e+01
# [10:18:41] < Debug >     ASC_MI:  0.8241735
# [10:18:41] < Debug >     ASC_OC: -0.04817121
# [10:18:41] < Debug >     ASC_RY:    1.39016
# [10:18:41] < Debug >     ASC_SC:   1.161907
# [10:18:41] < Debug >     ASC_SG:   2.619727
# [10:18:41] < Debug >     ASC_YK:   2.397613
# [10:18:41] < Debug >     B_DIST: -0.1416096
# [10:18:41] < General >   Log likelihood (N=6329):  -6819.591 Gradient norm:          3
# [10:18:41] < Debug >     ASC_MI:  0.8249376
# [10:18:41] < Debug >     ASC_OC: -0.04591891
# [10:18:41] < Debug >     ASC_RY:   1.391948
# [10:18:41] < Debug >     ASC_SC:    1.16324
# [10:18:41] < Debug >     ASC_SG:   2.621222
# [10:18:41] < Debug >     ASC_YK:    2.40001
# [10:18:41] < Debug >     B_DIST: -0.1416345
# [10:18:41] < General >   Log likelihood (N=6329):   -6819.59 Gradient norm:          3
# [10:18:41] < Debug >     ASC_MI:  0.8196096
# [10:18:41] < Debug >     ASC_OC: -0.04573808
# [10:18:41] < Debug >     ASC_RY:   1.391587
# [10:18:41] < Debug >     ASC_SC:   1.159065
# [10:18:41] < Debug >     ASC_SG:    2.62321
# [10:18:41] < Debug >     ASC_YK:   2.401189
# [10:18:41] < Debug >     B_DIST: -0.1414106
# [10:18:41] < General >   Log likelihood (N=6329):  -6819.598 Gradient norm:      4e+01
# [10:18:41] < Debug >     ASC_MI:  0.8237949
# [10:18:41] < Debug >     ASC_OC: -0.04588013
# [10:18:41] < Debug >     ASC_RY:    1.39187
# [10:18:41] < Debug >     ASC_SC:   1.162345
# [10:18:41] < Debug >     ASC_SG:   2.621649
# [10:18:41] < Debug >     ASC_YK:   2.400263
# [10:18:41] < Debug >     B_DIST: -0.1415865
# [10:18:41] < General >   Log likelihood (N=6329):   -6819.59 Gradient norm:          7
# [10:18:42] < Debug >     ASC_MI:  0.8247525
# [10:18:42] < Debug >     ASC_OC: -0.04515442
# [10:18:42] < Debug >     ASC_RY:   1.393089
# [10:18:42] < Debug >     ASC_SC:   1.162867
# [10:18:42] < Debug >     ASC_SG:   2.622647
# [10:18:42] < Debug >     ASC_YK:   2.401497
# [10:18:42] < Debug >     B_DIST: -0.1415971
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.589 Gradient norm:          6
# [10:18:42] < Debug >     ASC_MI:  0.8254944
# [10:18:42] < Debug >     ASC_OC: -0.04556923
# [10:18:42] < Debug >     ASC_RY:   1.395191
# [10:18:42] < Debug >     ASC_SC:   1.160711
# [10:18:42] < Debug >     ASC_SG:   2.623609
# [10:18:42] < Debug >     ASC_YK:   2.402821
# [10:18:42] < Debug >     B_DIST: -0.1416436
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.586 Gradient norm:          2
# [10:18:42] < Debug >     ASC_MI:  0.8254366
# [10:18:42] < Debug >     ASC_OC: -0.04729453
# [10:18:42] < Debug >     ASC_RY:   1.394977
# [10:18:42] < Debug >     ASC_SC:   1.158397
# [10:18:42] < Debug >     ASC_SG:   2.623006
# [10:18:42] < Debug >     ASC_YK:   2.402036
# [10:18:42] < Debug >     B_DIST: -0.1416496
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.585 Gradient norm:          2
# [10:18:42] < Debug >     ASC_MI:  0.8266756
# [10:18:42] < Debug >     ASC_OC: -0.04762675
# [10:18:42] < Debug >     ASC_RY:    1.39479
# [10:18:42] < Debug >     ASC_SC:   1.156599
# [10:18:42] < Debug >     ASC_SG:   2.622933
# [10:18:42] < Debug >     ASC_YK:   2.401626
# [10:18:42] < Debug >     B_DIST: -0.1416422
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.582 Gradient norm:          2
# [10:18:42] < Debug >     ASC_MI:  0.8314448
# [10:18:42] < Debug >     ASC_OC: -0.04369989
# [10:18:42] < Debug >     ASC_RY:   1.394553
# [10:18:42] < Debug >     ASC_SC:   1.152827
# [10:18:42] < Debug >     ASC_SG:    2.62361
# [10:18:42] < Debug >     ASC_YK:   2.402423
# [10:18:42] < Debug >     B_DIST: -0.1416284
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:        0.7
# [10:18:42] < Debug >     ASC_MI:  0.8280556
# [10:18:42] < Debug >     ASC_OC: -0.04460038
# [10:18:42] < Debug >     ASC_RY:   1.391868
# [10:18:42] < Debug >     ASC_SC:   1.149788
# [10:18:42] < Debug >     ASC_SG:   2.621047
# [10:18:42] < Debug >     ASC_YK:   2.399623
# [10:18:42] < Debug >     B_DIST: -0.1416513
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:          4
# [10:18:42] < Debug >     ASC_MI:  0.8304309
# [10:18:42] < Debug >     ASC_OC: -0.04396928
# [10:18:42] < Debug >     ASC_RY:   1.393749
# [10:18:42] < Debug >     ASC_SC:   1.151918
# [10:18:42] < Debug >     ASC_SG:   2.622843
# [10:18:42] < Debug >     ASC_YK:   2.401585
# [10:18:42] < Debug >     B_DIST: -0.1416353
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:          2
# [10:18:42] < Debug >     ASC_MI:  0.8317184
# [10:18:42] < Debug >     ASC_OC: -0.04238204
# [10:18:42] < Debug >     ASC_RY:   1.394632
# [10:18:42] < Debug >     ASC_SC:   1.152734
# [10:18:42] < Debug >     ASC_SG:   2.623248
# [10:18:42] < Debug >     ASC_YK:   2.401773
# [10:18:42] < Debug >     B_DIST: -0.1415761
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:          6
# [10:18:42] < Debug >     ASC_MI:  0.8306757
# [10:18:42] < Debug >     ASC_OC: -0.04366747
# [10:18:42] < Debug >     ASC_RY:   1.393917
# [10:18:42] < Debug >     ASC_SC:   1.152073
# [10:18:42] < Debug >     ASC_SG:    2.62292
# [10:18:42] < Debug >     ASC_YK:   2.401621
# [10:18:42] < Debug >     B_DIST:  -0.141624
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:        0.3
# [10:18:42] < Debug >     ASC_MI:  0.8310797
# [10:18:42] < Debug >     ASC_OC: -0.04322449
# [10:18:42] < Debug >     ASC_RY:   1.393992
# [10:18:42] < Debug >     ASC_SC:   1.152318
# [10:18:42] < Debug >     ASC_SG:   2.623172
# [10:18:42] < Debug >     ASC_YK:   2.401903
# [10:18:42] < Debug >     B_DIST: -0.1416252
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:        0.3
# [10:18:42] < Debug >     ASC_MI:  0.8307933
# [10:18:42] < Debug >     ASC_OC: -0.04387295
# [10:18:42] < Debug >     ASC_RY:    1.39324
# [10:18:42] < Debug >     ASC_SC:   1.151936
# [10:18:42] < Debug >     ASC_SG:   2.622467
# [10:18:42] < Debug >     ASC_YK:   2.401798
# [10:18:42] < Debug >     B_DIST:  -0.141623
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:          2
# [10:18:42] < Debug >     ASC_MI:  0.8310296
# [10:18:42] < Debug >     ASC_OC: -0.04333802
# [10:18:42] < Debug >     ASC_RY:    1.39386
# [10:18:42] < Debug >     ASC_SC:   1.152251
# [10:18:42] < Debug >     ASC_SG:   2.623049
# [10:18:42] < Debug >     ASC_YK:   2.401885
# [10:18:42] < Debug >     B_DIST: -0.1416248
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:        0.1
# [10:18:42] < Debug >     ASC_MI:  0.8311371
# [10:18:42] < Debug >     ASC_OC: -0.04317399
# [10:18:42] < Debug >     ASC_RY:   1.393898
# [10:18:42] < Debug >     ASC_SC:   1.152408
# [10:18:42] < Debug >     ASC_SG:   2.623149
# [10:18:42] < Debug >     ASC_YK:   2.401978
# [10:18:42] < Debug >     B_DIST: -0.1416251
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:       0.03
# [10:18:42] < Debug >     ASC_MI:  0.8311177
# [10:18:42] < Debug >     ASC_OC: -0.0431798
# [10:18:42] < Debug >     ASC_RY:   1.393889
# [10:18:42] < Debug >     ASC_SC:   1.152406
# [10:18:42] < Debug >     ASC_SG:   2.623151
# [10:18:42] < Debug >     ASC_YK:   2.401974
# [10:18:42] < Debug >     B_DIST: -0.1416242
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:        0.1
# [10:18:42] < Debug >     ASC_MI:  0.8311322
# [10:18:42] < Debug >     ASC_OC: -0.04317546
# [10:18:42] < Debug >     ASC_RY:   1.393895
# [10:18:42] < Debug >     ASC_SC:   1.152407
# [10:18:42] < Debug >     ASC_SG:   2.623149
# [10:18:42] < Debug >     ASC_YK:   2.401977
# [10:18:42] < Debug >     B_DIST: -0.1416248
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:       0.01
# [10:18:42] < Debug >     ASC_MI:  0.8311315
# [10:18:42] < Debug >     ASC_OC: -0.04317694
# [10:18:42] < Debug >     ASC_RY:   1.393893
# [10:18:42] < Debug >     ASC_SC:   1.152418
# [10:18:42] < Debug >     ASC_SG:   2.623148
# [10:18:42] < Debug >     ASC_YK:   2.401974
# [10:18:42] < Debug >     B_DIST: -0.1416249
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:      0.003
# [10:18:42] < Debug >     ASC_MI:  0.8311305
# [10:18:42] < Debug >     ASC_OC: -0.04318413
# [10:18:42] < Debug >     ASC_RY:   1.393888
# [10:18:42] < Debug >     ASC_SC:   1.152418
# [10:18:42] < Debug >     ASC_SG:   2.623143
# [10:18:42] < Debug >     ASC_YK:   2.401968
# [10:18:42] < Debug >     B_DIST: -0.1416248
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0009
# [10:18:42] < Debug >     ASC_MI:  0.8311306
# [10:18:42] < Debug >     ASC_OC: -0.04318694
# [10:18:42] < Debug >     ASC_RY:   1.393886
# [10:18:42] < Debug >     ASC_SC:   1.152415
# [10:18:42] < Debug >     ASC_SG:   2.623142
# [10:18:42] < Debug >     ASC_YK:   2.401965
# [10:18:42] < Debug >     B_DIST: -0.1416248
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:      0.002
# [10:18:42] < Debug >     ASC_MI:  0.8311306
# [10:18:42] < Debug >     ASC_OC: -0.04318545
# [10:18:42] < Debug >     ASC_RY:   1.393887
# [10:18:42] < Debug >     ASC_SC:   1.152417
# [10:18:42] < Debug >     ASC_SG:   2.623143
# [10:18:42] < Debug >     ASC_YK:   2.401967
# [10:18:42] < Debug >     B_DIST: -0.1416248
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:42] < Debug >     ASC_MI:  0.8311312
# [10:18:42] < Debug >     ASC_OC: -0.04318551
# [10:18:42] < Debug >     ASC_RY:   1.393887
# [10:18:42] < Debug >     ASC_SC:   1.152417
# [10:18:42] < Debug >     ASC_SG:   2.623143
# [10:18:42] < Debug >     ASC_YK:   2.401966
# [10:18:42] < Debug >     B_DIST: -0.1416248
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:      4e-05
# [10:18:42] < Debug >     ASC_MI:  0.8311307
# [10:18:42] < Debug >     ASC_OC: -0.04318546
# [10:18:42] < Debug >     ASC_RY:   1.393887
# [10:18:42] < Debug >     ASC_SC:   1.152417
# [10:18:42] < Debug >     ASC_SG:   2.623143
# [10:18:42] < Debug >     ASC_YK:   2.401967
# [10:18:42] < Debug >     B_DIST: -0.1416248
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0007
# [10:18:42] < Debug >     ASC_MI:  0.8311306
# [10:18:42] < Debug >     ASC_OC: -0.04318545
# [10:18:42] < Debug >     ASC_RY:   1.393887
# [10:18:42] < Debug >     ASC_SC:   1.152417
# [10:18:42] < Debug >     ASC_SG:   2.623143
# [10:18:42] < Debug >     ASC_YK:   2.401967
# [10:18:42] < Debug >     B_DIST: -0.1416248
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:42] < Debug >     ASC_MI:  0.8311306
# [10:18:42] < Debug >     ASC_OC: -0.04318545
# [10:18:42] < Debug >     ASC_RY:   1.393887
# [10:18:42] < Debug >     ASC_SC:   1.152417
# [10:18:42] < Debug >     ASC_SG:   2.623143
# [10:18:42] < Debug >     ASC_YK:   2.401967
# [10:18:42] < Debug >     B_DIST: -0.1416248
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:42] < Debug >     ASC_MI:  0.8311306
# [10:18:42] < Debug >     ASC_OC: -0.04318545
# [10:18:42] < Debug >     ASC_RY:   1.393887
# [10:18:42] < Debug >     ASC_SC:   1.152417
# [10:18:42] < Debug >     ASC_SG:   2.623143
# [10:18:42] < Debug >     ASC_YK:   2.401967
# [10:18:42] < Debug >     B_DIST: -0.1416248
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:42] < Debug >     ASC_MI:  0.8311306
# [10:18:42] < Debug >     ASC_OC: -0.04318545
# [10:18:42] < Debug >     ASC_RY:   1.393887
# [10:18:42] < Debug >     ASC_SC:   1.152417
# [10:18:42] < Debug >     ASC_SG:   2.623143
# [10:18:42] < Debug >     ASC_YK:   2.401967
# [10:18:42] < Debug >     B_DIST: -0.1416248
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:42] < Debug >     ASC_MI:  0.8311306
# [10:18:42] < Debug >     ASC_OC: -0.04318545
# [10:18:42] < Debug >     ASC_RY:   1.393887
# [10:18:42] < Debug >     ASC_SC:   1.152417
# [10:18:42] < Debug >     ASC_SG:   2.623143
# [10:18:42] < Debug >     ASC_YK:   2.401967
# [10:18:42] < Debug >     B_DIST: -0.1416248
# [10:18:42] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416249
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:       0.02
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0004
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:43] < Debug >     ASC_MI:  0.8311306
# [10:18:43] < Debug >     ASC_OC: -0.04318545
# [10:18:43] < Debug >     ASC_RY:   1.393887
# [10:18:43] < Debug >     ASC_SC:   1.152417
# [10:18:43] < Debug >     ASC_SG:   2.623143
# [10:18:43] < Debug >     ASC_YK:   2.401967
# [10:18:43] < Debug >     B_DIST: -0.1416248
# [10:18:43] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:44] < Debug >     ASC_MI:  0.8311306
# [10:18:44] < Debug >     ASC_OC: -0.04318545
# [10:18:44] < Debug >     ASC_RY:   1.393887
# [10:18:44] < Debug >     ASC_SC:   1.152417
# [10:18:44] < Debug >     ASC_SG:   2.623143
# [10:18:44] < Debug >     ASC_YK:   2.401967
# [10:18:44] < Debug >     B_DIST: -0.1416248
# [10:18:44] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0004
# [10:18:44] < Debug >     ASC_MI:  0.8311306
# [10:18:44] < Debug >     ASC_OC: -0.04318545
# [10:18:44] < Debug >     ASC_RY:   1.393887
# [10:18:44] < Debug >     ASC_SC:   1.152417
# [10:18:44] < Debug >     ASC_SG:   2.623143
# [10:18:44] < Debug >     ASC_YK:   2.401967
# [10:18:44] < Debug >     B_DIST: -0.1416248
# [10:18:44] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:44] < Debug >     ASC_MI:  0.8311306
# [10:18:44] < Debug >     ASC_OC: -0.04318545
# [10:18:44] < Debug >     ASC_RY:   1.393887
# [10:18:44] < Debug >     ASC_SC:   1.152417
# [10:18:44] < Debug >     ASC_SG:   2.623143
# [10:18:44] < Debug >     ASC_YK:   2.401967
# [10:18:44] < Debug >     B_DIST: -0.1416248
# [10:18:44] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:44] < Debug >     ASC_MI:  0.8311306
# [10:18:44] < Debug >     ASC_OC: -0.04318545
# [10:18:44] < Debug >     ASC_RY:   1.393887
# [10:18:44] < Debug >     ASC_SC:   1.152417
# [10:18:44] < Debug >     ASC_SG:   2.623143
# [10:18:44] < Debug >     ASC_YK:   2.401967
# [10:18:44] < Debug >     B_DIST: -0.1416248
# [10:18:44] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:44] < Debug >     ASC_MI:  0.8311306
# [10:18:44] < Debug >     ASC_OC: -0.04318545
# [10:18:44] < Debug >     ASC_RY:   1.393887
# [10:18:44] < Debug >     ASC_SC:   1.152417
# [10:18:44] < Debug >     ASC_SG:   2.623143
# [10:18:44] < Debug >     ASC_YK:   2.401967
# [10:18:44] < Debug >     B_DIST: -0.1416248
# [10:18:44] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:44] < Debug >     ASC_MI:  0.8311306
# [10:18:44] < Debug >     ASC_OC: -0.04318545
# [10:18:44] < Debug >     ASC_RY:   1.393887
# [10:18:44] < Debug >     ASC_SC:   1.152417
# [10:18:44] < Debug >     ASC_SG:   2.623143
# [10:18:44] < Debug >     ASC_YK:   2.401967
# [10:18:44] < Debug >     B_DIST: -0.1416248
# [10:18:44] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:44] < Debug >     ASC_MI:  0.8311306
# [10:18:44] < Debug >     ASC_OC: -0.04318545
# [10:18:44] < Debug >     ASC_RY:   1.393887
# [10:18:44] < Debug >     ASC_SC:   1.152417
# [10:18:44] < Debug >     ASC_SG:   2.623143
# [10:18:44] < Debug >     ASC_YK:   2.401967
# [10:18:44] < Debug >     B_DIST: -0.1416248
# [10:18:44] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:44] < Debug >     ASC_MI:  0.8311306
# [10:18:44] < Debug >     ASC_OC: -0.04318545
# [10:18:44] < Debug >     ASC_RY:   1.393887
# [10:18:44] < Debug >     ASC_SC:   1.152417
# [10:18:44] < Debug >     ASC_SG:   2.623143
# [10:18:44] < Debug >     ASC_YK:   2.401967
# [10:18:44] < Debug >     B_DIST: -0.1416248
# [10:18:44] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:44] < Debug >     ASC_MI:  0.8311306
# [10:18:44] < Debug >     ASC_OC: -0.04318545
# [10:18:44] < Debug >     ASC_RY:   1.393887
# [10:18:44] < Debug >     ASC_SC:   1.152417
# [10:18:44] < Debug >     ASC_SG:   2.623143
# [10:18:44] < Debug >     ASC_YK:   2.401967
# [10:18:44] < Debug >     B_DIST: -0.1416248
# [10:18:44] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:44] < Debug >     ASC_MI:  0.8311306
# [10:18:44] < Debug >     ASC_OC: -0.04318545
# [10:18:44] < Debug >     ASC_RY:   1.393887
# [10:18:44] < Debug >     ASC_SC:   1.152417
# [10:18:44] < Debug >     ASC_SG:   2.623143
# [10:18:44] < Debug >     ASC_YK:   2.401967
# [10:18:44] < Debug >     B_DIST: -0.1416248
# [10:18:44] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:44] < Debug >     ASC_MI:  0.8311306
# [10:18:44] < Debug >     ASC_OC: -0.04318545
# [10:18:44] < Debug >     ASC_RY:   1.393887
# [10:18:44] < Debug >     ASC_SC:   1.152417
# [10:18:44] < Debug >     ASC_SG:   2.623143
# [10:18:44] < Debug >     ASC_YK:   2.401967
# [10:18:44] < Debug >     B_DIST: -0.1416248
# [10:18:44] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:44] < Debug >     ASC_MI:  0.8311306
# [10:18:44] < Debug >     ASC_OC: -0.04318545
# [10:18:44] < Debug >     ASC_RY:   1.393887
# [10:18:44] < Debug >     ASC_SC:   1.152417
# [10:18:44] < Debug >     ASC_SG:   2.623143
# [10:18:44] < Debug >     ASC_YK:   2.401967
# [10:18:44] < Debug >     B_DIST: -0.1416248
# [10:18:44] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:44] < Debug >     ASC_MI:  0.8311306
# [10:18:44] < Debug >     ASC_OC: -0.04318545
# [10:18:44] < Debug >     ASC_RY:   1.393887
# [10:18:44] < Debug >     ASC_SC:   1.152417
# [10:18:44] < Debug >     ASC_SG:   2.623143
# [10:18:44] < Debug >     ASC_YK:   2.401967
# [10:18:44] < Debug >     B_DIST: -0.1416248
# [10:18:44] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:44] < Debug >     ASC_MI:  0.8311306
# [10:18:44] < Debug >     ASC_OC: -0.04318545
# [10:18:44] < Debug >     ASC_RY:   1.393887
# [10:18:44] < Debug >     ASC_SC:   1.152417
# [10:18:44] < Debug >     ASC_SG:   2.623143
# [10:18:44] < Debug >     ASC_YK:   2.401967
# [10:18:44] < Debug >     B_DIST: -0.1416248
# [10:18:44] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:44] < Debug >     ASC_MI:  0.8311306
# [10:18:44] < Debug >     ASC_OC: -0.04318545
# [10:18:44] < Debug >     ASC_RY:   1.393887
# [10:18:44] < Debug >     ASC_SC:   1.152417
# [10:18:44] < Debug >     ASC_SG:   2.623143
# [10:18:44] < Debug >     ASC_YK:   2.401967
# [10:18:44] < Debug >     B_DIST: -0.1416248
# [10:18:44] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:44] < Debug >     ASC_MI:  0.8311306
# [10:18:44] < Debug >     ASC_OC: -0.04318545
# [10:18:44] < Debug >     ASC_RY:   1.393887
# [10:18:44] < Debug >     ASC_SC:   1.152417
# [10:18:44] < Debug >     ASC_SG:   2.623143
# [10:18:44] < Debug >     ASC_YK:   2.401967
# [10:18:44] < Debug >     B_DIST: -0.1416248
# [10:18:44] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:44] < Debug >     ASC_MI:  0.8311306
# [10:18:44] < Debug >     ASC_OC: -0.04318545
# [10:18:44] < Debug >     ASC_RY:   1.393887
# [10:18:44] < Debug >     ASC_SC:   1.152417
# [10:18:44] < Debug >     ASC_SG:   2.623143
# [10:18:44] < Debug >     ASC_YK:   2.401967
# [10:18:44] < Debug >     B_DIST: -0.1416248
# [10:18:44] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:44] < Debug >     ASC_MI:  0.8311306
# [10:18:44] < Debug >     ASC_OC: -0.04318545
# [10:18:44] < Debug >     ASC_RY:   1.393887
# [10:18:44] < Debug >     ASC_SC:   1.152417
# [10:18:44] < Debug >     ASC_SG:   2.623143
# [10:18:44] < Debug >     ASC_YK:   2.401967
# [10:18:44] < Debug >     B_DIST: -0.1416248
# [10:18:44] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:44] < Debug >     ASC_MI:  0.8311306
# [10:18:44] < Debug >     ASC_OC: -0.04318545
# [10:18:44] < Debug >     ASC_RY:   1.393887
# [10:18:44] < Debug >     ASC_SC:   1.152417
# [10:18:44] < Debug >     ASC_SG:   2.623143
# [10:18:44] < Debug >     ASC_YK:   2.401967
# [10:18:44] < Debug >     B_DIST: -0.1416248
# [10:18:44] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008
# [10:18:44] < Debug >     ASC_MI:  0.8311306
# [10:18:44] < Debug >     ASC_OC: -0.04318545
# [10:18:44] < Debug >     ASC_RY:   1.393887
# [10:18:44] < Debug >     ASC_SC:   1.152417
# [10:18:44] < Debug >     ASC_SG:   2.623143
# [10:18:44] < Debug >     ASC_YK:   2.401967
# [10:18:44] < Debug >     B_DIST: -0.1416248
# [10:18:44] < General >   Log likelihood (N=6329):  -6819.577 Gradient norm:     0.0008 Hessian norm:       2e+05 BHHH norm:       2e+05
# [10:18:44] < General >   Results saved in file SMTO_Other.html
# [10:18:44] < General >   Results saved in file SMTO_Other.pickle
# [10:18:44] < General >   Log file created: SMTO_Other.log
# ASC_MI    =	0.831
# ASC_OC    =	-0.0432
# ASC_RY    =	1.39
# ASC_SC    =	1.15
# ASC_SG    =	2.62
# ASC_YK    =	2.4
# B_DIST    =	-0.142
#            Value   Std err     t-test       p-value  Rob. Std err  \
# ASC_MI  0.831131  0.122778   6.769387  1.293299e-11      0.122574
# ASC_OC -0.043185  0.114927  -0.375765  7.070918e-01      0.114341
# ASC_RY  1.393887  0.098952  14.086483  0.000000e+00      0.098846
# ASC_SC  1.152417  0.121218   9.506942  0.000000e+00      0.121619
# ASC_SG  2.623143  0.095149  27.568756  0.000000e+00      0.094543
# ASC_YK  2.401967  0.098881  24.291557  0.000000e+00      0.097691
# B_DIST -0.141625  0.002612 -54.225996  0.000000e+00      0.002672
#
#         Rob. t-test  Rob. p-value
# ASC_MI     6.780626  1.196554e-11
# ASC_OC    -0.377689  7.056616e-01
# ASC_RY    14.101668  0.000000e+00
# ASC_SC     9.475608  0.000000e+00
# ASC_SG    27.745467  0.000000e+00
# ASC_YK    24.587349  0.000000e+00
# B_DIST   -53.011691  0.000000e+00

# %%
"""
# Definition of the model. This is the contribution of each
# observation to the log likelihood function.
logprob = models.loglogit(V, av, Campus)

# Define level of verbosity
import biogeme.messaging as msg
logger = msg.bioMessage()
logger.setDebug()
#logger.setWarning()
#logger.setGeneral()
#logger.setDetailed()

# Create the Biogeme object
biogeme  = bio.BIOGEME(database,logprob,numberOfThreads=1)
biogeme.modelName = "SMTO_Logit"


# Estimate the parameters
results = biogeme.estimate(saveIterations=True)
biogeme.createLogFile()

# Print the estimated values
betas = results.getBetaValues()
for k,v in betas.items():
    print(f"{k:10}=\t{v:.3g}")

# Get the results in a pandas table
pandasResults = results.getEstimatedParameters()
print(pandasResults)
"""
pass

# %% [markdown]
# Upon running, this produces several output files. The most important is the html file.
#
# ### Resources
# UT Austin example: https://www.youtube.com/watch?v=QeJgyBIaXMQ
# Biogeme example: https://www.youtube.com/watch?v=OiM94B8WayA
# Nested logit example: https://www.youtube.com/watch?v=vEhvf54IKvs
