# %%
import pandas as pd
df = pd.read_csv('Subsetted.csv', index_col=0)
df.head()
# Out:
#    HomeZone  SchoolZone SchoolCode  Age Sex License Occupation  \
# 1       264          25       9244   19   M       N          O
# 2        38          25       9243   22   M       Y          S
# 3      1039          25       9244   26   M       Y          O
# 4       613          25       9244   19   M       Y          O
# 7      2053          25       9244   31   F       Y          G
#
#   EmploymentStatus StudentStatus  Vehicles  IncomeClass  Adults  Children  \
# 1                O             S         2            3       5         0
# 2                P             S         0            3       2         0
# 3                O             S         3            7       5         1
# 4                O             S         1            2       4         0
# 7                F             P         1            7       2         0
#
#    ExpansionFactor ModeTakenToSchool  TripToSchoolTime       Dist  PD  \
# ...

# %%
smto_2015_schools = ('UNIVERSITY OF TORONTO - ST GEORGE CAMPUS',
                    'YORK UNIVERSITY - YORK (KEELE & STEELES)',
                    'RYERSON POLYTECHNIC UNIVERSITY',
                    'UNIVERSITY OF TORONTO -  SCARBOROUGH CAMPUS',
                    'UNIVERSITY OF TORONTO -  MISSISSAUGA CAMPUS',
                    'ONTARIO COLLEGE OF ART & DESIGN',
                    'YORK UNIVERSITY - GLENDON CAMPUS')
df = df[df['SchoolName'].isin(smto_2015_schools)]

# %%
replacements = ('SG', 'YK', 'RY', 'SC', 'MI', 'OC', 'YK')
df.replace({school: code for school, clo})
